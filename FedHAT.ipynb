# %%
# %% [markdown]
# Stage 3 - Federated Learning for Cross-Country Iris Recognition (SwinV2 Tiny, CPU-only)

# %%
import os, json, random, time, pathlib
from dataclasses import dataclass, field
from typing import Dict, List, Tuple
import copy


import numpy as np
from PIL import Image

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, Sampler
from sklearn.metrics import roc_auc_score, roc_curve

try:
    import timm
except Exception as e:
    timm = None
    print("⚠️ timm is not installed. Install with: pip install timm")

# ---------------------- Global Config ----------------------
SEED = 42
random.seed(SEED); np.random.seed(SEED); torch.manual_seed(SEED)
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", DEVICE)

INPUT_SIZE   = (64, 512)    # (H, W)
BATCH_SIZE   = 32
EMBED_DIM    = 256
MARGIN       = 0.3
TEMPERATURE  = 0.07
CLIP_NORM    = 5.0

# PK
P_IDENTITIES = 16
K_IMAGES     = 2

# Paths 
RESULTS_ROOT = r"C:\Users\awais\OneDrive\Desktop\Thesis\Eye_Results"
SPLITS_DIR   = r"C:\Users\awais\OneDrive\Desktop\Thesis\splits\Eyes\FIHR"
MODELS_ROOT  = r"C:\Users\awais\OneDrive\Desktop\Thesis\Eye_Results"
FL_MODELS_ROOT = os.path.join(MODELS_ROOT, "FL_Stage3")
os.makedirs(FL_MODELS_ROOT, exist_ok=True)

DATASETS = {
    "Pakistan": r"C:\Users\awais\OneDrive\Desktop\Thesis\Pakistan\PakIris_Normalized_Aug",
    "China":    r"C:\Users\awais\OneDrive\Desktop\Thesis\China\CASIA-Iris-Interval_Normalized_Aug",
    "Czech":    r"C:\Users\awais\OneDrive\Desktop\Thesis\Czech\CzechIris_Normalized_Enhanced_FIHR",
    "India":    r"C:\Users\awais\OneDrive\Desktop\Thesis\India\IITD_Normalized",
    "Iraq":     r"C:\Users\awais\OneDrive\Desktop\Thesis\Iraq\AMF_Normalized_Enhanced_FIHR",
    "Malaysia": r"C:\Users\awais\OneDrive\Desktop\Thesis\Malaysia\MMU_Normalized_Enhanced_FIHR",
    "Iran":    r"C:\Users\awais\OneDrive\Desktop\Thesis\Iran\Iris_Normalized_Enhanced_FIHR"
}

def log(msg, level="INFO", dataset=None, model=None):
    prefix = f"[{level}]"
    if dataset and model: prefix += f" [{dataset} | {model}]"
    elif dataset:         prefix += f" [{dataset}]"
    elif model:           prefix += f" [{model}]"
    print(f"{prefix} {msg}")
# Out:
# Using device: cuda

# %%
# %% [markdown]
# Cell 2 - JSON train/val/test splits & mean/std

# %%
def load_json_split(dataset_name: str, dataset_root: str):
    """
    Loads train/val/test split from JSON in SPLITS_DIR.
    Keeps your original structure.
    """
    fp = os.path.join(SPLITS_DIR, f"{dataset_name.lower()}_split.json")
    if not os.path.exists(fp):
        raise FileNotFoundError(fp)
    with open(fp, 'r', encoding='utf-8') as f:
        data = json.load(f)

    def finalize(lst):
        items = []
        for itm in lst:
            if isinstance(itm, (list, tuple)):
                path, lbl = itm[0], itm[1] if len(itm) > 1 else None
            elif isinstance(itm, dict):
                path = itm.get('path') or itm.get('image') or next(iter(itm.values()))
                lbl  = itm.get('label')
            else:
                path, lbl = itm, None
            abs_path = path if os.path.isabs(path) else os.path.join(dataset_root, path)
            if lbl is None:
                lbl = pathlib.Path(abs_path).parent.name
            items.append((abs_path, lbl))
        return items

    train = finalize(data.get('train', []))
    val   = finalize(data.get('val', []))
    test  = finalize(data.get('test', []))

    classes = sorted({l for _, l in train + val + test})
    log(f"Loaded {dataset_name}: train={len(train)}, val={len(val)}, test={len(test)}, classes={len(classes)}",
        "SPLIT", dataset_name)
    return {'train': train, 'val': val, 'test': test, 'classes': classes}

def estimate_mean_std(items: List[Tuple[str,str]], max_samples: int = 512):
    sel = items if len(items) <= max_samples else random.sample(items, max_samples)
    m = 0.0; s2 = 0.0; n = 0
    for p,_ in sel:
        with Image.open(p) as im:
            arr = np.asarray(im.convert('L'), dtype=np.float32) / 255.0
        m_batch = arr.mean(); s2_batch = arr.var(); k = arr.size
        new_n = n + k
        delta = m_batch - m
        m = m + delta * (k / new_n)
        s2 = (n*s2 + k*s2_batch + (delta**2)*n*k/new_n) / new_n
        n = new_n
    return float(m), float(np.sqrt(max(s2, 1e-8)))

# %%
# %% [markdown]
# Cell 3 - Siamese Train Dataset, PKSampler, IndexDataset

# %%
from torchvision import transforms

class SiameseTrainSet(Dataset):
    """Grayscale 64×512 with augmentations for metric learning."""
    def __init__(self, items, label_to_idx, mean, std):
        self.items = items
        self.label_to_idx = label_to_idx
        self.mean, self.std = mean, std

        self.by_lbl: Dict[str, List[int]] = {}
        for i, (_, l) in enumerate(items):
            self.by_lbl.setdefault(l, []).append(i)

        self.tx = transforms.Compose([
            transforms.Grayscale(1),
            transforms.Resize(INPUT_SIZE),
            transforms.RandomAffine(degrees=10, translate=(0.05, 0.05), scale=(0.9, 1.1)),
            transforms.ColorJitter(brightness=0.3, contrast=0.3),
            transforms.RandomHorizontalFlip(p=0.5),
            transforms.ToTensor(),
            transforms.Normalize([self.mean], [self.std]),
            transforms.RandomErasing(p=0.3, scale=(0.02, 0.1), ratio=(0.3, 3.3)),
        ])

    def __len__(self): return len(self.items)

    def load(self, idx: int):
        p, l = self.items[idx]
        img = Image.open(p).convert('L')
        x = self.tx(img)  # (1,64,512)
        return x, self.label_to_idx[l]

class PKSampler(Sampler[List[int]]):
    """Yield batches as P identities × K images indices."""
    def __init__(self, items, P=16, K=2, shuffle=True):
        self.items = items
        self.P, self.K = P, K
        self.shuffle = shuffle
        self.by_lbl: Dict[str, List[int]] = {}
        for i, (_, l) in enumerate(items):
            self.by_lbl.setdefault(l, []).append(i)
        self.labels = [l for l, idxs in self.by_lbl.items() if len(idxs) >= K]

    def __iter__(self):
        labels = self.labels.copy()
        if self.shuffle: random.shuffle(labels)
        for i in range(0, len(labels), self.P):
            grp = labels[i:i+self.P]
            if len(grp) < self.P: break
            idxs = []
            for l in grp:
                pool = self.by_lbl[l]
                sel = random.sample(pool, self.K) if self.shuffle else pool[:self.K]
                idxs.extend(sel)
            yield idxs

    def __len__(self):
        return max(0, len(self.labels)//self.P)

class IndexDataset(Dataset):
    """Returns just an index i; used with PKSampler."""
    def __init__(self, n): self.n = n
    def __len__(self): return self.n
    def __getitem__(self, i): return int(i)

# %%
# %% [markdown]
# Cell 4 - Metric-learning losses + ROC/EER evaluation (with interpolation)

# %%
def pairwise_sim(z):
    z = F.normalize(z, dim=1)
    return z @ z.t()

def batch_hard_triplet_loss(z, y, margin=MARGIN):
    y = y.view(-1,1)
    S = pairwise_sim(z)
    D = torch.clamp(2 - 2*S, min=0.0)
    M = (y==y.t())
    pos = (D * M).where(M, torch.tensor(-1., device=D.device)).max(1).values
    neg = (D + 1e6*M.float()).min(1).values
    return F.relu(pos - neg + margin).mean()

def supervised_contrastive_loss(z, y, temperature=TEMPERATURE):
    z = F.normalize(z, dim=1)
    S = z @ z.t() / temperature
    y = y.view(-1,1)
    mask = (y==y.t()).float()
    logits_mask = torch.ones_like(mask) - torch.eye(mask.shape[0], device=mask.device)
    mask = mask * logits_mask
    log_prob = S - torch.logsumexp(S * logits_mask - 1e9*(1-logits_mask), dim=1, keepdim=True)
    pos_count = mask.sum(1).clamp_min(1.0)
    return (-(mask * log_prob).sum(1) / pos_count).mean()


# ---------- Interpolated EER and TAR@FAR helpers ----------

def _eer_from_fpr_tpr_interp(fpr, tpr):
    """
    EER via interpolation between the two points where fpr-fnr changes sign.
    Falls back to closest point if no sign change.
    """
    fnr = 1.0 - tpr
    diff = fpr - fnr

    # If never crosses zero, fall back to nearest point
    if np.all(diff >= 0) or np.all(diff <= 0):
        i = int(np.nanargmin(np.abs(diff)))
        return float(max(fpr[i], fnr[i]))

    # indices where sign changes between i and i+1
    idx = np.where(np.sign(diff[:-1]) != np.sign(diff[1:]))[0]
    i0 = int(idx[0])
    i1 = i0 + 1

    # linear interpolation on diff -> 0
    d0, d1 = diff[i0], diff[i1]
    t = d0 / (d0 - d1 + 1e-12)

    x0, x1 = fpr[i0], fpr[i1]
    eer = x0 + t * (x1 - x0)
    return float(eer)


def _tar_at_far_interp(fpr, tpr, far):
    """
    TAR at given FAR using linear interpolation on (fpr, tpr).
    """
    fpr = np.asarray(fpr)
    tpr = np.asarray(tpr)

    if fpr.size == 0:
        return float("nan")

    if far <= fpr[0]:
        return float(tpr[0])
    if far >= fpr[-1]:
        return float(tpr[-1])

    idx1 = int(np.searchsorted(fpr, far))
    idx0 = idx1 - 1

    x0, x1 = fpr[idx0], fpr[idx1]
    y0, y1 = tpr[idx0], tpr[idx1]

    if x1 == x0:
        return float(y0)

    alpha = (far - x0) / (x1 - x0)
    tar = y0 + alpha * (y1 - y0)
    return float(tar)


@torch.no_grad()
def compute_embeddings(model, items, mean, std, batch_size=BATCH_SIZE):
    """
    Evaluation pipeline:
    - grayscale
    - resize to (64, 512)
    - normalize with dataset-specific mean/std
    - L2-normalized embeddings from the FL model
    """
    tx = transforms.Compose([
        transforms.Grayscale(1),
        transforms.Resize(INPUT_SIZE),
        transforms.ToTensor(),
        transforms.Normalize([mean], [std]),
    ])

    class _EvalSet(Dataset):
        def __init__(self, items):
            self.items = items
        def __len__(self):
            return len(self.items)
        def __getitem__(self, i):
            p, l = self.items[i]
            img = Image.open(p).convert("L")
            x = tx(img)
            return x, l

    pin = (DEVICE.type == "cuda")
    loader = DataLoader(
        _EvalSet(items),
        batch_size=batch_size,
        shuffle=False,
        num_workers=0,
        pin_memory=pin,
    )

    model.eval()
    feats, labels = [], []
    for xb, yb in loader:
        xb = xb.to(DEVICE, non_blocking=pin)
        z = model(xb).cpu()
        feats.append(z)
        labels.extend(yb)

    return torch.cat(feats).numpy(), np.array(labels)


def evaluate_embeddings(feats, labels):
    """
    Given embeddings and identity labels, computes:
    - ROC-AUC
    - EER (interpolated)
    - TAR@FAR=0.01 and 0.001 (interpolated)
    """
    if len(labels) < 2:
        return {
            "roc_auc": float("nan"),
            "eer": float("nan"),
            "tar1": float("nan"),
            "tar01": float("nan"),
        }

    # cosine similarities of L2-normalized embeddings
    Z = torch.tensor(feats, dtype=torch.float32)
    Z = F.normalize(Z, dim=1)
    S = (Z @ Z.t()).numpy()

    m = labels.reshape(-1, 1) == labels.reshape(1, -1)
    iu = np.triu_indices_from(S, 1)
    y_true = m[iu].astype(np.uint8)
    y_score = S[iu]

    if len(np.unique(y_true)) < 2:
        return {
            "roc_auc": float("nan"),
            "eer": float("nan"),
            "tar1": float("nan"),
            "tar01": float("nan"),
        }

    fpr, tpr, _ = roc_curve(y_true, y_score)
    auc  = float(roc_auc_score(y_true, y_score))
    eer  = _eer_from_fpr_tpr_interp(fpr, tpr)
    tar1 = _tar_at_far_interp(fpr, tpr, 0.01)
    tar01= _tar_at_far_interp(fpr, tpr, 0.001)

    return {
        "roc_auc": auc,
        "eer": eer,
        "tar1": tar1,
        "tar01": tar01,
    }

# %%
# %% [markdown]
# Cell 5 - SwinV2 Tiny Siamese (timm)

# %%
class SwinV2_Tiny_Siamese(nn.Module):
    def __init__(self, embed_dim=EMBED_DIM):
        super().__init__()
        if timm is None:
            raise RuntimeError("timm is required for SwinV2_Tiny_Siamese. Install via pip.")
        m = timm.create_model(
            'swinv2_tiny_window8_256',  # as used in centralized training
            pretrained=True,
            num_classes=0,
            in_chans=1,
            img_size=INPUT_SIZE,
        )
        feat_dim = m.num_features
        self.backbone = m
        self.proj = nn.Sequential(
            nn.Linear(feat_dim, feat_dim),
            nn.GELU(),
            nn.LayerNorm(feat_dim),
            nn.Linear(feat_dim, embed_dim),
        )
    def forward(self, x):
        f = self.backbone(x)
        z = self.proj(f)
        return F.normalize(z, p=2, dim=1)

def swin_model_fn():
    return SwinV2_Tiny_Siamese(embed_dim=EMBED_DIM)

# %%
# %% [markdown]
# Cell 6 - FL configs (ONLY FHIR with polynomial-learned weights)

from dataclasses import dataclass, field
import random
import numpy as np
import torch

# ---------------- Training ----------------
@dataclass
class FLTrainConfig:
    rounds: int = 200
    local_epochs: int = 1
    eval_every: int = 5
    patience: int = 20
    fp16_comms: bool = True

# ---------------- Optimizers (client) ----------------
@dataclass
class FLOptimConfig:
    lr: float = 1e-4
    weight_decay: float = 1e-4
    betas: tuple = (0.9, 0.999)

# ---------------- Loss ----------------
@dataclass
class FLLossConfig:
    supcon_weight: float = 0.5
    margin: float = MARGIN
    temperature: float = TEMPERATURE

# ---------------- FHIR + POLY settings ----------------
@dataclass
class FHIRPolyConfig:
    # Warmup: run OG-FHIR for 30-50 rounds to collect training data
    warmup_rounds: int = 50

    # Polynomial regression (degree 2)
    poly_degree: int = 2
    ridge_alpha: float = 1e-2  # regularization

    # how many (round,client) samples before first fit
    min_fit_samples: int = 80   # 7 clients * ~12 eval steps ≈ 84

    # score stability
    score_floor: float = 1e-6

# ---------------- OG-FHIR weights (warmup only) ----------------
@dataclass
class FHIRWeightConfig:
    alpha_size: float    = 0.35   # α log(1 + N_k)
    beta_div: float      = 0.25   # β (q_k / N_k)
    gamma_quality: float = 0.25   # γ Q_k
    delta_rarity: float  = 0.15   # δ (1 / sqrt(q_k))

@dataclass
class FLExperimentConfig:
    train: FLTrainConfig = field(default_factory=FLTrainConfig)
    optim: FLOptimConfig = field(default_factory=FLOptimConfig)
    loss: FLLossConfig   = field(default_factory=FLLossConfig)

    # Only one strategy now
    strategy: str = "fhir_poly"   # <- ONLY strategy used

    # Warmup OG-FHIR weights + polynomial learner config
    fhir: FHIRWeightConfig = field(default_factory=FHIRWeightConfig)
    poly: FHIRPolyConfig   = field(default_factory=FHIRPolyConfig)

def set_global_seed(seed: int = SEED):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)

# %%
# %% [markdown]
# Cell 7 - Minimal server state (ONLY FHIR)

from dataclasses import dataclass
import copy
import torch

@dataclass
class ServerState:
    global_weights: dict
    round: int = 0

class Strategy:
    def init_state(self, model_fn):
        model = model_fn()
        return ServerState(global_weights=copy.deepcopy(model.state_dict()))

def build_strategy(name: str) -> Strategy:
    # only one supported strategy now
    if name != "fhir_poly":
        raise ValueError(f"Unsupported strategy: {name}. Use 'fhir_poly' only.")
    return Strategy()

# %%
# %% [markdown]
# Cell 8 - Prepare FL client data (splits, label maps, mean/std)

# %%
from collections import namedtuple
import copy

FLClientData = namedtuple("FLClientData", ["name", "train_items", "val_items", "test_items",
                                           "label_to_idx", "mean", "std"])

def prepare_fl_clients():
    splits = {d: load_json_split(d, r) for d, r in DATASETS.items()}
    mean_std_cache = {}
    clients_data = {}

    for ds_name, split in splits.items():
        label_to_idx = {l: i for i, l in enumerate(split['classes'])}

        if ds_name not in mean_std_cache:
            m, s = estimate_mean_std(split['train'])
            mean_std_cache[ds_name] = (m, s)
            log(f"[FL] mean/std for {ds_name} = ({m:.3f}, {s:.3f})",
                "FL-NORM", ds_name, "SwinV2_Tiny_Siamese")
        mean, std = mean_std_cache[ds_name]

        clients_data[ds_name] = FLClientData(
            name=ds_name,
            train_items=split['train'],
            val_items=split['val'],
            test_items=split['test'],
            label_to_idx=label_to_idx,
            mean=mean,
            std=std
        )
    return clients_data

fl_clients_data = prepare_fl_clients()
# Out:
# [SPLIT] [Pakistan] Loaded Pakistan: train=2304, val=288, test=288, classes=720
# [SPLIT] [China] Loaded China: train=2106, val=256, test=277, classes=395
# [SPLIT] [Czech] Loaded Czech: train=312, val=36, test=36, classes=128
# [SPLIT] [India] Loaded India: train=1756, val=209, test=215, classes=425
# [SPLIT] [Iraq] Loaded Iraq: train=440, val=50, test=50, classes=108
# [SPLIT] [Malaysia] Loaded Malaysia: train=365, val=45, test=40, classes=90
# [SPLIT] [Iran] Loaded Iran: train=633, val=80, test=79, classes=158
# [FL-NORM] [Pakistan | SwinV2_Tiny_Siamese] [FL] mean/std for Pakistan = (0.361, 0.125)
# [FL-NORM] [China | SwinV2_Tiny_Siamese] [FL] mean/std for China = (0.505, 0.267)
# [FL-NORM] [Czech | SwinV2_Tiny_Siamese] [FL] mean/std for Czech = (0.366, 0.175)
# [FL-NORM] [India | SwinV2_Tiny_Siamese] [FL] mean/std for India = (0.264, 0.195)
# [FL-NORM] [Iraq | SwinV2_Tiny_Siamese] [FL] mean/std for Iraq = (0.367, 0.168)
# [FL-NORM] [Malaysia | SwinV2_Tiny_Siamese] [FL] mean/std for Malaysia = (0.324, 0.185)
# [FL-NORM] [Iran | SwinV2_Tiny_Siamese] [FL] mean/std for Iran = (0.324, 0.187)

# %%
# %% [markdown]
# Cell 9 - FLClient class (local training loop)

# %%
class FLClient:
    def __init__(self, client_data: FLClientData,
                 cfg: FLExperimentConfig,
                 model_fn,
                 prox_mu: float = 0.0):
        self.data = client_data
        self.cfg = cfg
        self.model_fn = model_fn
        self.prox_mu = prox_mu

        self.train_set = SiameseTrainSet(
            items=self.data.train_items,
            label_to_idx=self.data.label_to_idx,
            mean=self.data.mean,
            std=self.data.std
        )

    def _prox_term(self, model, global_weights):
        """FedProx / FHIR-Prox proximal regularization term."""
        if self.prox_mu <= 0.0:
            return torch.tensor(0., device=DEVICE)

        prox = torch.tensor(0., device=DEVICE)
        for (n, p) in model.named_parameters():
            if p.requires_grad:
                prox = prox + torch.sum((p - global_weights[n].to(p.device)) ** 2)
        return 0.5 * self.prox_mu * prox

    def train_one_round(self, global_weights: dict):
        device = DEVICE
        model = self.model_fn().to(device)
        model.load_state_dict(copy.deepcopy(global_weights), strict=True)
        model.train()

        opt_cfg = self.cfg.optim
        opt = torch.optim.AdamW(
            model.parameters(),
            lr=opt_cfg.lr,
            weight_decay=opt_cfg.weight_decay,
            betas=opt_cfg.betas
        )

        total_loss = 0.0
        total_batches = 0

        for _ in range(self.cfg.train.local_epochs):
            pk_sampler = PKSampler(
                self.data.train_items,
                P=P_IDENTITIES,
                K=K_IMAGES,
                shuffle=True,
            )

            # IMPORTANT: keep this single-process (num_workers=0)
            # to avoid DataLoader worker crashes on Windows / notebooks.
            train_loader = DataLoader(
                IndexDataset(len(self.data.train_items)),
                batch_sampler=pk_sampler,
                num_workers=0,      # <- no multiprocessing workers
                pin_memory=False,   # GPU still works; this only affects host→device copies
            )

            for batch_idx in train_loader:
                xb, yb = [], []
                for idx in batch_idx.tolist():
                    x, y = self.train_set.load(int(idx))
                    xb.append(x)
                    yb.append(y)

                x = torch.stack(xb).to(device)
                y = torch.tensor(yb, dtype=torch.long).to(device)

                opt.zero_grad(set_to_none=True)
                z = model(x)

                # Metric-learning losses
                l_trip = batch_hard_triplet_loss(
                    z, y,
                    margin=self.cfg.loss.margin
                )
                l_sup = supervised_contrastive_loss(
                    z, y,
                    temperature=self.cfg.loss.temperature
                )

                loss = l_trip + self.cfg.loss.supcon_weight * l_sup

                # FedProx / FHIR-Prox proximal term (0 if mu == 0)
                loss = loss + self._prox_term(model, global_weights)

                loss.backward()
                nn.utils.clip_grad_norm_(model.parameters(), CLIP_NORM)
                opt.step()

                total_loss += float(loss)
                total_batches += 1

        avg_loss = total_loss / max(1, total_batches)
        updated = copy.deepcopy(model.state_dict())

        # Compress updates to fp16 for communication if enabled
        if self.cfg.train.fp16_comms:
            for k in updated:
                updated[k] = updated[k].to(torch.float16).cpu()

        return updated, avg_loss

# %%
# %% [markdown]
# Cell 10 - Global evaluation on val/test of each client

# %%
def evaluate_global_on_clients(model_fn, global_state_dict, fl_clients_data: dict, split_type="val"):
    results = {}
    for name, cdata in fl_clients_data.items():
        items = cdata.val_items if split_type == "val" else cdata.test_items
        model = model_fn().to(DEVICE)
        model.load_state_dict(global_state_dict, strict=True)
        feats, labels = compute_embeddings(model, items, cdata.mean, cdata.std)
        metrics = evaluate_embeddings(feats, labels)
        results[name] = metrics
    return results

# %%
# ============================================================
# Cell 11 - FL server training loop (ONLY FHIR warmup + POLY learned weights)
#   Improvements:
#   1) StandardScaler before poly expansion
#   2) Softplus positivity instead of clipping
#   3) Explicit weights_next_round (computed at eval, applied next round) -> no leakage
# ============================================================

import math
import copy
import numpy as np
import torch

from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.linear_model import Ridge

def _fmt_named(vals_by_name, order, nd=3):
    return ", ".join([f"{n}:{vals_by_name[n]:.{nd}f}" for n in order])

@torch.no_grad()
def _eval_one_client(model_fn, state_dict, cdata):
    """Evaluate ONLY on a single client's val split and return metrics dict."""
    model = model_fn().to(DEVICE)
    model.load_state_dict(state_dict, strict=True)
    feats, labels = compute_embeddings(model, cdata.val_items, cdata.mean, cdata.std)
    return evaluate_embeddings(feats, labels)

def _softplus_np(x):
    # numerically stable softplus: log(1 + exp(x))
    # for large x, softplus(x) ~ x
    x = np.asarray(x, dtype=np.float32)
    return np.log1p(np.exp(-np.abs(x))) + np.maximum(x, 0)

def train_federated(model_fn,
                    fl_clients_data: dict,
                    cfg: FLExperimentConfig):

    set_global_seed(SEED)
    strategy = build_strategy(cfg.strategy)
    state = strategy.init_state(model_fn)

    # ---------------- Build Clients ----------------
    clients = []
    for name, cdata in fl_clients_data.items():
        clients.append(FLClient(cdata, cfg, model_fn, prox_mu=0.0))

    client_names = [cl.data.name for cl in clients]
    num_clients = len(client_names)

    # ---------------- Precompute N_k, q_k and OG terms (for warmup only) ----------------
    stats_by_name = {}
    for cl in clients:
        n_k = len(cl.data.train_items)
        q_k = len(cl.data.label_to_idx)
        stats_by_name[cl.data.name] = {
            "n": n_k,
            "q": q_k,
            "size_score": math.log(1.0 + float(n_k)),
            "id_score": float(q_k) / max(float(n_k), 1.0),
            "rarity_score": 1.0 / math.sqrt(max(float(q_k), 1.0)),
        }

    # Warmup quality scores Q_k for OG-FHIR (only used during warmup)
    quality_scores = {n: 1.0 for n in client_names}

    # ---------------- Polynomial regression buffers ----------------
    # X_k = [EER, TAR1, TAR01, log1p(Nk), log1p(qk)]
    # y_k = utility = max(0, EER_global_on_client - EER_clientupd_on_client)
    X_buf = []
    y_buf = []

    # poly learner objects
    poly = PolynomialFeatures(degree=cfg.poly.poly_degree, include_bias=False)
    scaler = StandardScaler(with_mean=True, with_std=True)
    poly_model = None

    # cache weights to use in next round (NO leakage)
    # Round 1 uses uniform by default
    weights_next_round = {n: 1.0 / num_clients for n in client_names}

    def _fit_poly_if_ready():
        nonlocal poly_model, scaler
        if len(X_buf) < int(cfg.poly.min_fit_samples):
            return False

        X = np.asarray(X_buf, dtype=np.float32)
        y = np.asarray(y_buf, dtype=np.float32)

        # scale -> poly -> ridge
        scaler.fit(X)
        Xs = scaler.transform(X)
        Xp = poly.fit_transform(Xs)

        reg = Ridge(alpha=float(cfg.poly.ridge_alpha), fit_intercept=True, random_state=SEED)
        reg.fit(Xp, y)
        poly_model = reg
        return True

    def _predict_scores(metrics_by_client):
        """
        metrics_by_client: dict[name] = {eer, tar1, tar01}
        returns score_by_client (positive scores)
        """
        if poly_model is None:
            # uniform until fitted
            return {n: 1.0 for n in client_names}

        X = []
        for n in client_names:
            m = metrics_by_client[n]
            st = stats_by_name[n]
            X.append([
                float(m["eer"]),
                float(m["tar1"]),
                float(m["tar01"]),
                float(np.log1p(st["n"])),
                float(np.log1p(st["q"])),
            ])
        X = np.asarray(X, dtype=np.float32)

        # IMPORTANT: use same scaler as training
        Xs = scaler.transform(X)
        Xp = poly.transform(Xs)  # poly already fitted in _fit_poly_if_ready

        raw = poly_model.predict(Xp).astype(np.float32)

        # Softplus -> strictly positive, smooth
        pos = _softplus_np(raw) + float(cfg.poly.score_floor)

        return {n: float(v) for n, v in zip(client_names, pos.tolist())}

    # ---------------------------------------------------------------
    best_state = copy.deepcopy(state)
    best_round = 0
    best_macro_eer = float("inf")
    bad_rounds = 0

    # ---------------- Federated Rounds ----------------
    for r in range(cfg.train.rounds):
        round_id = r + 1
        log(f"==== [FL] Round {round_id}/{cfg.train.rounds} | strategy={cfg.strategy} ====", "FL")

        # snapshot of global before local training (used for utility labels)
        global_pre = {k: v.to(torch.float32) for k, v in state.global_weights.items()}

        # ---- Local training ----
        client_updates = []
        for client in clients:
            upd, avg_loss = client.train_one_round(global_pre)
            log(f"Client {client.data.name}: avg_loss={avg_loss:.4f}", "FL-CLIENT")
            for k in upd:
                upd[k] = upd[k].to(torch.float32)
            client_updates.append(upd)

        # ---- Aggregation weights (NO leakage) ----
        in_warmup = (round_id <= int(cfg.poly.warmup_rounds))

        if in_warmup:
            # OG-FHIR warmup weights (computed from current Q_k)
            alpha = cfg.fhir.alpha_size
            beta  = cfg.fhir.beta_div
            gamma = cfg.fhir.gamma_quality
            delta = cfg.fhir.delta_rarity

            raw = {}
            for n in client_names:
                st = stats_by_name[n]
                w_k = (
                    alpha * st["size_score"] +
                    beta  * st["id_score"] +
                    gamma * float(quality_scores.get(n, 1.0)) +
                    delta * st["rarity_score"]
                )
                raw[n] = float(max(w_k, 1e-6))

            w_sum = sum(raw.values()) + 1e-12
            alphas = {n: raw[n] / w_sum for n in client_names}
            log(f"FHIR weights (WARMUP-OG): { _fmt_named(alphas, client_names, nd=4) }", "FL-WEIGHTS")

        else:
            # Poly weights for THIS round come from weights_next_round
            alphas = dict(weights_next_round)
            log(f"FHIR weights (POLY, from prev eval): { _fmt_named(alphas, client_names, nd=4) }", "FL-WEIGHTS")

        # ---- Apply aggregation ----
        new_global = {k: torch.zeros_like(v) for k, v in global_pre.items()}
        for n, upd in zip(client_names, client_updates):
            a_k = float(alphas[n])
            for k in new_global:
                new_global[k] += a_k * upd[k]

        state.global_weights = new_global
        state.round += 1

        # ---- Periodic Evaluation ----
        if (round_id) % cfg.train.eval_every == 0:
            log("Evaluating global model on validation splits...", "FL-EVAL")

            metrics = evaluate_global_on_clients(
                model_fn,
                state.global_weights,
                fl_clients_data,
                split_type="val"
            )

            for cname, m in metrics.items():
                log(f"  {cname}: EER={m['eer']:.4f}, "
                    f"TAR@1%={m['tar1']:.4f}, TAR@0.1%={m['tar01']:.4f}",
                    "FL-METRIC")

            # ---- During warmup: update Q_k (normalized EER) ----
            if in_warmup:
                eers = [m["eer"] for m in metrics.values() if np.isfinite(m["eer"])]
                if len(eers) > 0:
                    e_min = float(min(eers))
                    e_max = float(max(eers))
                    span = max(e_max - e_min, 1e-6)
                    for cname, m in metrics.items():
                        e = m["eer"]
                        if np.isfinite(e):
                            q_norm = 1.0 - (float(e) - e_min) / span
                            quality_scores[cname] = float(q_norm)
                    log(f"Quality Q_k (warmup OG): { _fmt_named(quality_scores, client_names) }", "FL-Q")

            # ---- Collect regression samples (X,y) using EER utility ----
            log("Collecting POLY regression samples (EER utility)...", "FL-POLY")

            for n, upd in zip(client_names, client_updates):
                cdata = fl_clients_data[n]

                base_m = _eval_one_client(model_fn, global_pre, cdata)
                upd_m  = _eval_one_client(model_fn, upd, cdata)

                if not (np.isfinite(base_m["eer"]) and np.isfinite(upd_m["eer"])):
                    continue

                st = stats_by_name[n]
                Xk = [
                    float(metrics[n]["eer"]),
                    float(metrics[n]["tar1"]),
                    float(metrics[n]["tar01"]),
                    float(np.log1p(st["n"])),
                    float(np.log1p(st["q"])),
                ]
                yk = max(0.0, float(base_m["eer"]) - float(upd_m["eer"]))

                X_buf.append(Xk)
                y_buf.append(yk)

            log(f"POLY buffer size: {len(X_buf)} samples", "FL-POLY")

            # ---- Fit poly model once warmup is done and enough samples exist ----
            fitted_now = False
            if (round_id >= int(cfg.poly.warmup_rounds)) and (len(X_buf) >= int(cfg.poly.min_fit_samples)):
                fitted_now = _fit_poly_if_ready()
                if fitted_now:
                    log("POLY model: fitted/updated (scaled -> degree-2 poly -> ridge).", "FL-POLY")

            # ---- Compute weights for NEXT round (no leakage) ----
            if (round_id >= int(cfg.poly.warmup_rounds)) and (poly_model is not None):
                score_by = _predict_scores(metrics)
                s_sum = sum(score_by.values()) + 1e-12
                weights_next_round = {n: float(score_by[n] / s_sum) for n in client_names}
                log(f"POLY score s_k: { _fmt_named(score_by, client_names, nd=4) }", "FL-POLY")
                log(f"weights_next_round: { _fmt_named(weights_next_round, client_names, nd=4) }", "FL-POLY")
            elif (round_id >= int(cfg.poly.warmup_rounds)):
                # still not fitted -> keep uniform next round
                weights_next_round = {n: 1.0 / num_clients for n in client_names}

            # ---- Early stopping based on macro EER (global) ----
            valid_eers = [m["eer"] for m in metrics.values() if np.isfinite(m["eer"])]
            macro_eer = float(np.mean(valid_eers)) if len(valid_eers) else float("inf")
            log(f"  Macro-EER: {macro_eer:.4f}", "FL-MACRO")

            if np.isfinite(macro_eer) and macro_eer + 1e-5 < best_macro_eer:
                best_macro_eer = macro_eer
                best_round = round_id
                best_state = copy.deepcopy(state)
                bad_rounds = 0
                log(f"  ✅ New best macro-EER {best_macro_eer:.4f} at round {best_round}", "FL-BEST")
            else:
                bad_rounds += 1
                log(f"  No improvement. bad_rounds={bad_rounds}/{cfg.train.patience}", "FL-PATIENCE")
                if bad_rounds >= cfg.train.patience:
                    log(f"Early stopping at round {round_id}. "
                        f"Best macro-EER={best_macro_eer:.4f} @ round {best_round}",
                        "FL-STOP")
                    return best_state, {
                        "best_round": best_round,
                        "best_macro_eer": best_macro_eer,
                        "poly_samples": len(X_buf),
                        "poly_fitted": (poly_model is not None),
                    }

    return best_state, {
        "best_round": best_round,
        "best_macro_eer": best_macro_eer,
        "poly_samples": len(X_buf),
        "poly_fitted": (poly_model is not None),
    }

# %%
# ============================================================
# Cell 12 - FHIR (Warmup OG) -> POLY learned weights (EER utility): train + save best
# ============================================================

import torch
import os

fl_cfg = FLExperimentConfig()
fl_cfg.strategy = "fhir_poly"   # ONLY strategy now

# schedule
fl_cfg.train.rounds = 250
fl_cfg.train.local_epochs = 1
fl_cfg.train.eval_every = 1
fl_cfg.train.patience = 150
fl_cfg.loss.supcon_weight = 0.5

# warmup + poly settings
fl_cfg.poly.warmup_rounds = 50        
fl_cfg.poly.poly_degree = 2
fl_cfg.poly.ridge_alpha = 1e-2
fl_cfg.poly.min_fit_samples = 80

# OG-FHIR weights used ONLY during warmup
fl_cfg.fhir.alpha_size    = 0.35
fl_cfg.fhir.beta_div      = 0.25
fl_cfg.fhir.gamma_quality = 0.25
fl_cfg.fhir.delta_rarity  = 0.15

best_state, info = train_federated(
    model_fn=swin_model_fn,
    fl_clients_data=fl_clients_data,
    cfg=fl_cfg
)

print("✅ FHIR-POLY training finished.")
print(f"Best round: {info.get('best_round', None)}")
print(f"Best macro-EER: {info.get('best_macro_eer', None):.6f}")
print(f"Poly samples: {info.get('poly_samples', None)} | poly_fitted: {info.get('poly_fitted', None)}")

SAVE_PATH = r"C:\Users\awais\OneDrive\Desktop\Thesis\Eye_Results\FL_Stage3\FHIR_POLY_EER_best.pt"

global_weights = best_state.global_weights
global_weights_cpu = {k: v.cpu() for k, v in global_weights.items()}

torch.save({
    "global_model": global_weights_cpu,
    "best_round": info.get("best_round", None),
    "best_macro_eer": info.get("best_macro_eer", None),
    "strategy": "FHIR-POLY-EER",
    "poly_degree": fl_cfg.poly.poly_degree,
    "warmup_rounds": fl_cfg.poly.warmup_rounds,
}, SAVE_PATH)

print(f"💾 Model saved successfully at:\n{SAVE_PATH}")
# Out:
# [FL] ==== [FL] Round 1/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=1.0478
# [FL-CLIENT] Client China: avg_loss=1.6263
# [FL-CLIENT] Client Czech: avg_loss=1.5531
# [FL-CLIENT] Client India: avg_loss=0.9323
# [FL-CLIENT] Client Iraq: avg_loss=1.6854
# [FL-CLIENT] Client Malaysia: avg_loss=1.9171
# [FL-CLIENT] Client Iran: avg_loss=1.7054
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1622, China:0.1589, Czech:0.1266, India:0.1563, Iraq:0.1309, Malaysia:0.1275, Iran:0.1376
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0748, TAR@1%=0.7384, TAR@0.1%=0.5301
# [FL-METRIC]   China: EER=0.0847, TAR@1%=0.7170, TAR@0.1%=0.4721
# [FL-METRIC]   Czech: EER=0.0589, TAR@1%=0.6944, TAR@0.1%=0.5833
# [FL-METRIC]   India: EER=0.0348, TAR@1%=0.9351, TAR@0.1%=0.8798
# [FL-METRIC]   Iraq: EER=0.0791, TAR@1%=0.6900, TAR@0.1%=0.5000
# [FL-METRIC]   Malaysia: EER=0.0444, TAR@1%=0.7889, TAR@0.1%=0.4556
# [FL-METRIC]   Iran: EER=0.1242, TAR@1%=0.7205, TAR@0.1%=0.3292
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.552, China:0.442, Czech:0.730, India:1.000, Iraq:0.504, Malaysia:0.892, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 7 samples
# [FL-MACRO]   Macro-EER: 0.0716
# [FL-BEST]   ✅ New best macro-EER 0.0716 at round 1
# [FL] ==== [FL] Round 2/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.7186
# [FL-CLIENT] Client China: avg_loss=1.1207
# [FL-CLIENT] Client Czech: avg_loss=1.1078
# [FL-CLIENT] Client India: avg_loss=0.6130
# [FL-CLIENT] Client Iraq: avg_loss=1.1005
# [FL-CLIENT] Client Malaysia: avg_loss=1.3420
# [FL-CLIENT] Client Iran: avg_loss=1.2749
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1624, China:0.1575, Czech:0.1280, India:0.1625, Iraq:0.1293, Malaysia:0.1311, Iran:0.1292
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0417, TAR@1%=0.8681, TAR@0.1%=0.6505
# [FL-METRIC]   China: EER=0.0618, TAR@1%=0.7931, TAR@0.1%=0.5826
# [FL-METRIC]   Czech: EER=0.0278, TAR@1%=0.8611, TAR@0.1%=0.7778
# [FL-METRIC]   India: EER=0.0361, TAR@1%=0.9495, TAR@0.1%=0.9327
# [FL-METRIC]   Iraq: EER=0.0498, TAR@1%=0.9000, TAR@0.1%=0.8700
# [FL-METRIC]   Malaysia: EER=0.0833, TAR@1%=0.7556, TAR@0.1%=0.5667
# [FL-METRIC]   Iran: EER=0.1127, TAR@1%=0.6957, TAR@0.1%=0.2112
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.836, China:0.599, Czech:1.000, India:0.903, Iraq:0.741, Malaysia:0.346, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 14 samples
# [FL-MACRO]   Macro-EER: 0.0590
# [FL-BEST]   ✅ New best macro-EER 0.0590 at round 2
# [FL] ==== [FL] Round 3/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.5965
# [FL-CLIENT] Client China: avg_loss=0.8154
# [FL-CLIENT] Client Czech: avg_loss=0.7643
# [FL-CLIENT] Client India: avg_loss=0.4795
# [FL-CLIENT] Client Iraq: avg_loss=0.7326
# [FL-CLIENT] Client Malaysia: avg_loss=1.0200
# [FL-CLIENT] Client Iran: avg_loss=1.1315
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1657, China:0.1590, Czech:0.1311, India:0.1605, Iraq:0.1320, Malaysia:0.1230, Iran:0.1287
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0417, TAR@1%=0.8981, TAR@0.1%=0.7060
# [FL-METRIC]   China: EER=0.0583, TAR@1%=0.7979, TAR@0.1%=0.6112
# [FL-METRIC]   Czech: EER=0.0135, TAR@1%=0.9722, TAR@0.1%=0.9444
# [FL-METRIC]   India: EER=0.0259, TAR@1%=0.9615, TAR@0.1%=0.9399
# [FL-METRIC]   Iraq: EER=0.0453, TAR@1%=0.8800, TAR@0.1%=0.8400
# [FL-METRIC]   Malaysia: EER=0.0444, TAR@1%=0.9000, TAR@0.1%=0.6444
# [FL-METRIC]   Iran: EER=0.0994, TAR@1%=0.7702, TAR@0.1%=0.4534
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.672, China:0.479, Czech:1.000, India:0.855, Iraq:0.629, Malaysia:0.639, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 21 samples
# [FL-MACRO]   Macro-EER: 0.0469
# [FL-BEST]   ✅ New best macro-EER 0.0469 at round 3
# [FL] ==== [FL] Round 4/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.4618
# [FL-CLIENT] Client China: avg_loss=0.7698
# [FL-CLIENT] Client Czech: avg_loss=0.5961
# [FL-CLIENT] Client India: avg_loss=0.3863
# [FL-CLIENT] Client Iraq: avg_loss=0.6760
# [FL-CLIENT] Client Malaysia: avg_loss=0.7402
# [FL-CLIENT] Client Iran: avg_loss=0.9239
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1637, China:0.1577, Czech:0.1314, India:0.1601, Iraq:0.1307, Malaysia:0.1273, Iran:0.1290
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0394, TAR@1%=0.9213, TAR@0.1%=0.7199
# [FL-METRIC]   China: EER=0.0609, TAR@1%=0.7990, TAR@0.1%=0.6504
# [FL-METRIC]   Czech: EER=0.0168, TAR@1%=0.9444, TAR@0.1%=0.8889
# [FL-METRIC]   India: EER=0.0240, TAR@1%=0.9639, TAR@0.1%=0.9375
# [FL-METRIC]   Iraq: EER=0.0356, TAR@1%=0.8900, TAR@0.1%=0.8300
# [FL-METRIC]   Malaysia: EER=0.0478, TAR@1%=0.8889, TAR@0.1%=0.6889
# [FL-METRIC]   Iran: EER=0.0870, TAR@1%=0.7640, TAR@0.1%=0.5031
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.679, China:0.372, Czech:1.000, India:0.897, Iraq:0.733, Malaysia:0.559, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 28 samples
# [FL-MACRO]   Macro-EER: 0.0445
# [FL-BEST]   ✅ New best macro-EER 0.0445 at round 4
# [FL] ==== [FL] Round 5/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.4084
# [FL-CLIENT] Client China: avg_loss=0.6823
# [FL-CLIENT] Client Czech: avg_loss=0.4750
# [FL-CLIENT] Client India: avg_loss=0.3097
# [FL-CLIENT] Client Iraq: avg_loss=0.4635
# [FL-CLIENT] Client Malaysia: avg_loss=0.8920
# [FL-CLIENT] Client Iran: avg_loss=0.8400
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1639, China:0.1563, Czech:0.1315, India:0.1608, Iraq:0.1322, Malaysia:0.1263, Iran:0.1290
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0347, TAR@1%=0.9398, TAR@0.1%=0.7870
# [FL-METRIC]   China: EER=0.0488, TAR@1%=0.8549, TAR@0.1%=0.7051
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0216, TAR@1%=0.9688, TAR@0.1%=0.9231
# [FL-METRIC]   Iraq: EER=0.0329, TAR@1%=0.9400, TAR@0.1%=0.9100
# [FL-METRIC]   Malaysia: EER=0.0378, TAR@1%=0.8333, TAR@0.1%=0.6222
# [FL-METRIC]   Iran: EER=0.0737, TAR@1%=0.7578, TAR@0.1%=0.6398
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.529, China:0.338, Czech:1.000, India:0.706, Iraq:0.554, Malaysia:0.487, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 35 samples
# [FL-MACRO]   Macro-EER: 0.0356
# [FL-BEST]   ✅ New best macro-EER 0.0356 at round 5
# [FL] ==== [FL] Round 6/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.3820
# [FL-CLIENT] Client China: avg_loss=0.6423
# [FL-CLIENT] Client Czech: avg_loss=0.5168
# [FL-CLIENT] Client India: avg_loss=0.2889
# [FL-CLIENT] Client Iraq: avg_loss=0.3458
# [FL-CLIENT] Client Malaysia: avg_loss=0.5967
# [FL-CLIENT] Client Iran: avg_loss=0.6828
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1632, China:0.1572, Czech:0.1326, India:0.1595, Iraq:0.1309, Malaysia:0.1264, Iran:0.1301
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0278, TAR@1%=0.9491, TAR@0.1%=0.8056
# [FL-METRIC]   China: EER=0.0526, TAR@1%=0.8442, TAR@0.1%=0.6801
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0125, TAR@1%=0.9832, TAR@0.1%=0.9615
# [FL-METRIC]   Iraq: EER=0.0373, TAR@1%=0.9400, TAR@0.1%=0.9300
# [FL-METRIC]   Malaysia: EER=0.0311, TAR@1%=0.8778, TAR@0.1%=0.7111
# [FL-METRIC]   Iran: EER=0.0774, TAR@1%=0.7950, TAR@0.1%=0.6957
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.641, China:0.320, Czech:1.000, India:0.839, Iraq:0.517, Malaysia:0.598, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 42 samples
# [FL-MACRO]   Macro-EER: 0.0341
# [FL-BEST]   ✅ New best macro-EER 0.0341 at round 6
# [FL] ==== [FL] Round 7/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.3561
# [FL-CLIENT] Client China: avg_loss=0.5825
# [FL-CLIENT] Client Czech: avg_loss=0.4376
# [FL-CLIENT] Client India: avg_loss=0.1834
# [FL-CLIENT] Client Iraq: avg_loss=0.3213
# [FL-CLIENT] Client Malaysia: avg_loss=0.5347
# [FL-CLIENT] Client Iran: avg_loss=0.7528
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1641, China:0.1563, Czech:0.1321, India:0.1607, Iraq:0.1298, Malaysia:0.1274, Iran:0.1296
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0278, TAR@1%=0.9606, TAR@0.1%=0.8287
# [FL-METRIC]   China: EER=0.0428, TAR@1%=0.8704, TAR@0.1%=0.6623
# [FL-METRIC]   Czech: EER=0.0051, TAR@1%=1.0000, TAR@0.1%=0.9722
# [FL-METRIC]   India: EER=0.0120, TAR@1%=0.9880, TAR@0.1%=0.9688
# [FL-METRIC]   Iraq: EER=0.0382, TAR@1%=0.9300, TAR@0.1%=0.9100
# [FL-METRIC]   Malaysia: EER=0.0300, TAR@1%=0.8556, TAR@0.1%=0.4000
# [FL-METRIC]   Iran: EER=0.0621, TAR@1%=0.7826, TAR@0.1%=0.6584
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.602, China:0.338, Czech:1.000, India:0.878, Iraq:0.419, Malaysia:0.563, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 49 samples
# [FL-MACRO]   Macro-EER: 0.0311
# [FL-BEST]   ✅ New best macro-EER 0.0311 at round 7
# [FL] ==== [FL] Round 8/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.2893
# [FL-CLIENT] Client China: avg_loss=0.4457
# [FL-CLIENT] Client Czech: avg_loss=0.4500
# [FL-CLIENT] Client India: avg_loss=0.2313
# [FL-CLIENT] Client Iraq: avg_loss=0.2522
# [FL-CLIENT] Client Malaysia: avg_loss=0.5370
# [FL-CLIENT] Client Iran: avg_loss=0.6734
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1638, China:0.1568, Czech:0.1323, India:0.1615, Iraq:0.1287, Malaysia:0.1271, Iran:0.1298
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0258, TAR@1%=0.9583, TAR@0.1%=0.8148
# [FL-METRIC]   China: EER=0.0383, TAR@1%=0.8716, TAR@0.1%=0.7241
# [FL-METRIC]   Czech: EER=0.0034, TAR@1%=1.0000, TAR@0.1%=0.9167
# [FL-METRIC]   India: EER=0.0120, TAR@1%=0.9880, TAR@0.1%=0.9543
# [FL-METRIC]   Iraq: EER=0.0320, TAR@1%=0.9400, TAR@0.1%=0.9000
# [FL-METRIC]   Malaysia: EER=0.0356, TAR@1%=0.7667, TAR@0.1%=0.4778
# [FL-METRIC]   Iran: EER=0.0620, TAR@1%=0.8323, TAR@0.1%=0.7081
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.617, China:0.405, Czech:1.000, India:0.852, Iraq:0.512, Malaysia:0.451, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 56 samples
# [FL-MACRO]   Macro-EER: 0.0299
# [FL-BEST]   ✅ New best macro-EER 0.0299 at round 8
# [FL] ==== [FL] Round 9/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.2990
# [FL-CLIENT] Client China: avg_loss=0.4463
# [FL-CLIENT] Client Czech: avg_loss=0.3060
# [FL-CLIENT] Client India: avg_loss=0.1843
# [FL-CLIENT] Client Iraq: avg_loss=0.3578
# [FL-CLIENT] Client Malaysia: avg_loss=0.5236
# [FL-CLIENT] Client Iran: avg_loss=0.5748
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1640, China:0.1576, Czech:0.1322, India:0.1611, Iraq:0.1299, Malaysia:0.1255, Iran:0.1297
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0208, TAR@1%=0.9630, TAR@0.1%=0.8542
# [FL-METRIC]   China: EER=0.0380, TAR@1%=0.8882, TAR@0.1%=0.7289
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0120, TAR@1%=0.9880, TAR@0.1%=0.9639
# [FL-METRIC]   Iraq: EER=0.0200, TAR@1%=0.9300, TAR@0.1%=0.9000
# [FL-METRIC]   Malaysia: EER=0.0267, TAR@1%=0.7778, TAR@0.1%=0.3889
# [FL-METRIC]   Iran: EER=0.0500, TAR@1%=0.8571, TAR@0.1%=0.7516
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.583, China:0.239, Czech:1.000, India:0.760, Iraq:0.600, Malaysia:0.467, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 63 samples
# [FL-MACRO]   Macro-EER: 0.0239
# [FL-BEST]   ✅ New best macro-EER 0.0239 at round 9
# [FL] ==== [FL] Round 10/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.2400
# [FL-CLIENT] Client China: avg_loss=0.5035
# [FL-CLIENT] Client Czech: avg_loss=0.3525
# [FL-CLIENT] Client India: avg_loss=0.1679
# [FL-CLIENT] Client Iraq: avg_loss=0.2522
# [FL-CLIENT] Client Malaysia: avg_loss=0.5507
# [FL-CLIENT] Client Iran: avg_loss=0.5546
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1639, China:0.1557, Czech:0.1326, India:0.1602, Iraq:0.1315, Malaysia:0.1260, Iran:0.1301
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0231, TAR@1%=0.9676, TAR@0.1%=0.8241
# [FL-METRIC]   China: EER=0.0399, TAR@1%=0.8966, TAR@0.1%=0.7551
# [FL-METRIC]   Czech: EER=0.0101, TAR@1%=0.9722, TAR@0.1%=0.9167
# [FL-METRIC]   India: EER=0.0168, TAR@1%=0.9832, TAR@0.1%=0.9760
# [FL-METRIC]   Iraq: EER=0.0300, TAR@1%=0.9000, TAR@0.1%=0.8900
# [FL-METRIC]   Malaysia: EER=0.0222, TAR@1%=0.8333, TAR@0.1%=0.6556
# [FL-METRIC]   Iran: EER=0.0420, TAR@1%=0.8758, TAR@0.1%=0.7019
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.591, China:0.067, Czech:1.000, India:0.789, Iraq:0.376, Malaysia:0.620, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 70 samples
# [FL-MACRO]   Macro-EER: 0.0263
# [FL-PATIENCE]   No improvement. bad_rounds=1/150
# [FL] ==== [FL] Round 11/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.2348
# [FL-CLIENT] Client China: avg_loss=0.3854
# [FL-CLIENT] Client Czech: avg_loss=0.2897
# [FL-CLIENT] Client India: avg_loss=0.1944
# [FL-CLIENT] Client Iraq: avg_loss=0.2055
# [FL-CLIENT] Client Malaysia: avg_loss=0.4645
# [FL-CLIENT] Client Iran: avg_loss=0.5864
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1645, China:0.1538, Czech:0.1329, India:0.1611, Iraq:0.1287, Malaysia:0.1285, Iran:0.1305
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0162, TAR@1%=0.9792, TAR@0.1%=0.8148
# [FL-METRIC]   China: EER=0.0357, TAR@1%=0.9073, TAR@0.1%=0.7432
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0168, TAR@1%=0.9832, TAR@0.1%=0.9591
# [FL-METRIC]   Iraq: EER=0.0231, TAR@1%=0.9200, TAR@0.1%=0.9000
# [FL-METRIC]   Malaysia: EER=0.0244, TAR@1%=0.7778, TAR@0.1%=0.5556
# [FL-METRIC]   Iran: EER=0.0435, TAR@1%=0.9006, TAR@0.1%=0.7205
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.627, China:0.180, Czech:1.000, India:0.613, Iraq:0.468, Malaysia:0.438, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 77 samples
# [FL-MACRO]   Macro-EER: 0.0228
# [FL-BEST]   ✅ New best macro-EER 0.0228 at round 11
# [FL] ==== [FL] Round 12/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.2204
# [FL-CLIENT] Client China: avg_loss=0.3606
# [FL-CLIENT] Client Czech: avg_loss=0.2764
# [FL-CLIENT] Client India: avg_loss=0.1522
# [FL-CLIENT] Client Iraq: avg_loss=0.1661
# [FL-CLIENT] Client Malaysia: avg_loss=0.4945
# [FL-CLIENT] Client Iran: avg_loss=0.5073
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1653, China:0.1556, Czech:0.1332, India:0.1589, Iraq:0.1302, Malaysia:0.1262, Iran:0.1307
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0183, TAR@1%=0.9676, TAR@0.1%=0.8449
# [FL-METRIC]   China: EER=0.0351, TAR@1%=0.9013, TAR@0.1%=0.7539
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9832
# [FL-METRIC]   Iraq: EER=0.0258, TAR@1%=0.9600, TAR@0.1%=0.9300
# [FL-METRIC]   Malaysia: EER=0.0222, TAR@1%=0.9000, TAR@0.1%=0.6333
# [FL-METRIC]   Iran: EER=0.0463, TAR@1%=0.8571, TAR@0.1%=0.7019
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.605, China:0.242, Czech:1.000, India:0.793, Iraq:0.444, Malaysia:0.521, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 84 samples
# [FL-MACRO]   Macro-EER: 0.0225
# [FL-BEST]   ✅ New best macro-EER 0.0225 at round 12
# [FL] ==== [FL] Round 13/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.2144
# [FL-CLIENT] Client China: avg_loss=0.3912
# [FL-CLIENT] Client Czech: avg_loss=0.2539
# [FL-CLIENT] Client India: avg_loss=0.1309
# [FL-CLIENT] Client Iraq: avg_loss=0.1904
# [FL-CLIENT] Client Malaysia: avg_loss=0.3212
# [FL-CLIENT] Client Iran: avg_loss=0.4988
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1643, China:0.1559, Czech:0.1326, India:0.1608, Iraq:0.1294, Malaysia:0.1269, Iran:0.1302
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0162, TAR@1%=0.9745, TAR@0.1%=0.8079
# [FL-METRIC]   China: EER=0.0380, TAR@1%=0.9061, TAR@0.1%=0.7574
# [FL-METRIC]   Czech: EER=0.0101, TAR@1%=0.9722, TAR@0.1%=0.9722
# [FL-METRIC]   India: EER=0.0102, TAR@1%=0.9880, TAR@0.1%=0.9663
# [FL-METRIC]   Iraq: EER=0.0302, TAR@1%=0.9100, TAR@0.1%=0.8900
# [FL-METRIC]   Malaysia: EER=0.0222, TAR@1%=0.8000, TAR@0.1%=0.4778
# [FL-METRIC]   Iran: EER=0.0360, TAR@1%=0.8944, TAR@0.1%=0.7267
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.781, China:0.000, Czech:1.000, India:0.997, Iraq:0.278, Malaysia:0.565, Iran:0.070
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 91 samples
# [FL-MACRO]   Macro-EER: 0.0233
# [FL-PATIENCE]   No improvement. bad_rounds=1/150
# [FL] ==== [FL] Round 14/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.2389
# [FL-CLIENT] Client China: avg_loss=0.4138
# [FL-CLIENT] Client Czech: avg_loss=0.2161
# [FL-CLIENT] Client India: avg_loss=0.1878
# [FL-CLIENT] Client Iraq: avg_loss=0.1975
# [FL-CLIENT] Client Malaysia: avg_loss=0.4580
# [FL-CLIENT] Client Iran: avg_loss=0.4065
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1666, China:0.1523, Czech:0.1325, India:0.1634, Iraq:0.1269, Malaysia:0.1273, Iran:0.1310
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0156, TAR@1%=0.9745, TAR@0.1%=0.8403
# [FL-METRIC]   China: EER=0.0315, TAR@1%=0.9227, TAR@0.1%=0.7574
# [FL-METRIC]   Czech: EER=0.0017, TAR@1%=1.0000, TAR@0.1%=0.9722
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9688
# [FL-METRIC]   Iraq: EER=0.0300, TAR@1%=0.8900, TAR@0.1%=0.8900
# [FL-METRIC]   Malaysia: EER=0.0222, TAR@1%=0.8889, TAR@0.1%=0.6000
# [FL-METRIC]   Iran: EER=0.0343, TAR@1%=0.8820, TAR@0.1%=0.7764
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.575, China:0.086, Czech:1.000, India:0.757, Iraq:0.133, Malaysia:0.371, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 98 samples
# [FL-MACRO]   Macro-EER: 0.0207
# [FL-BEST]   ✅ New best macro-EER 0.0207 at round 14
# [FL] ==== [FL] Round 15/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.1908
# [FL-CLIENT] Client China: avg_loss=0.3153
# [FL-CLIENT] Client Czech: avg_loss=0.3235
# [FL-CLIENT] Client India: avg_loss=0.1455
# [FL-CLIENT] Client Iraq: avg_loss=0.1375
# [FL-CLIENT] Client Malaysia: avg_loss=0.4377
# [FL-CLIENT] Client Iran: avg_loss=0.4732
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1655, China:0.1552, Czech:0.1339, India:0.1618, Iraq:0.1262, Malaysia:0.1260, Iran:0.1314
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0173, TAR@1%=0.9699, TAR@0.1%=0.8264
# [FL-METRIC]   China: EER=0.0357, TAR@1%=0.8894, TAR@0.1%=0.7432
# [FL-METRIC]   Czech: EER=0.0017, TAR@1%=1.0000, TAR@0.1%=0.9722
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9688
# [FL-METRIC]   Iraq: EER=0.0258, TAR@1%=0.9000, TAR@0.1%=0.8600
# [FL-METRIC]   Malaysia: EER=0.0300, TAR@1%=0.8111, TAR@0.1%=0.4444
# [FL-METRIC]   Iran: EER=0.0435, TAR@1%=0.8696, TAR@0.1%=0.7578
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.626, China:0.187, Czech:1.000, India:0.810, Iraq:0.424, Malaysia:0.322, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 105 samples
# [FL-MACRO]   Macro-EER: 0.0234
# [FL-PATIENCE]   No improvement. bad_rounds=1/150
# [FL] ==== [FL] Round 16/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.2070
# [FL-CLIENT] Client China: avg_loss=0.3166
# [FL-CLIENT] Client Czech: avg_loss=0.2232
# [FL-CLIENT] Client India: avg_loss=0.1439
# [FL-CLIENT] Client Iraq: avg_loss=0.1684
# [FL-CLIENT] Client Malaysia: avg_loss=0.4515
# [FL-CLIENT] Client Iran: avg_loss=0.4371
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1652, China:0.1556, Czech:0.1331, India:0.1615, Iraq:0.1295, Malaysia:0.1245, Iran:0.1306
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0214, TAR@1%=0.9722, TAR@0.1%=0.8333
# [FL-METRIC]   China: EER=0.0323, TAR@1%=0.9144, TAR@0.1%=0.7658
# [FL-METRIC]   Czech: EER=0.0051, TAR@1%=1.0000, TAR@0.1%=0.9722
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9639
# [FL-METRIC]   Iraq: EER=0.0267, TAR@1%=0.8800, TAR@0.1%=0.8600
# [FL-METRIC]   Malaysia: EER=0.0222, TAR@1%=0.8667, TAR@0.1%=0.6000
# [FL-METRIC]   Iran: EER=0.0373, TAR@1%=0.8571, TAR@0.1%=0.7516
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.493, China:0.155, Czech:1.000, India:0.858, Iraq:0.329, Malaysia:0.467, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 112 samples
# [FL-MACRO]   Macro-EER: 0.0221
# [FL-PATIENCE]   No improvement. bad_rounds=2/150
# [FL] ==== [FL] Round 17/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.1760
# [FL-CLIENT] Client China: avg_loss=0.3633
# [FL-CLIENT] Client Czech: avg_loss=0.2911
# [FL-CLIENT] Client India: avg_loss=0.1245
# [FL-CLIENT] Client Iraq: avg_loss=0.1962
# [FL-CLIENT] Client Malaysia: avg_loss=0.4808
# [FL-CLIENT] Client Iran: avg_loss=0.3892
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1635, China:0.1553, Czech:0.1332, India:0.1624, Iraq:0.1283, Malaysia:0.1266, Iran:0.1307
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0185, TAR@1%=0.9722, TAR@0.1%=0.8495
# [FL-METRIC]   China: EER=0.0306, TAR@1%=0.9144, TAR@0.1%=0.7919
# [FL-METRIC]   Czech: EER=0.0017, TAR@1%=1.0000, TAR@0.1%=0.9722
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9784
# [FL-METRIC]   Iraq: EER=0.0240, TAR@1%=0.8900, TAR@0.1%=0.8800
# [FL-METRIC]   Malaysia: EER=0.0222, TAR@1%=0.8778, TAR@0.1%=0.6222
# [FL-METRIC]   Iran: EER=0.0467, TAR@1%=0.8696, TAR@0.1%=0.7764
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.626, China:0.357, Czech:1.000, India:0.824, Iraq:0.504, Malaysia:0.544, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 119 samples
# [FL-MACRO]   Macro-EER: 0.0219
# [FL-PATIENCE]   No improvement. bad_rounds=3/150
# [FL] ==== [FL] Round 18/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.1740
# [FL-CLIENT] Client China: avg_loss=0.2829
# [FL-CLIENT] Client Czech: avg_loss=0.2080
# [FL-CLIENT] Client India: avg_loss=0.1101
# [FL-CLIENT] Client Iraq: avg_loss=0.1116
# [FL-CLIENT] Client Malaysia: avg_loss=0.3255
# [FL-CLIENT] Client Iran: avg_loss=0.4285
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1641, China:0.1569, Czech:0.1322, India:0.1606, Iraq:0.1298, Malaysia:0.1267, Iran:0.1297
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0185, TAR@1%=0.9745, TAR@0.1%=0.8681
# [FL-METRIC]   China: EER=0.0240, TAR@1%=0.9382, TAR@0.1%=0.8026
# [FL-METRIC]   Czech: EER=0.0017, TAR@1%=1.0000, TAR@0.1%=0.9722
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9736
# [FL-METRIC]   Iraq: EER=0.0249, TAR@1%=0.8900, TAR@0.1%=0.8700
# [FL-METRIC]   Malaysia: EER=0.0222, TAR@1%=0.8444, TAR@0.1%=0.6556
# [FL-METRIC]   Iran: EER=0.0493, TAR@1%=0.8944, TAR@0.1%=0.8075
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.647, China:0.533, Czech:1.000, India:0.834, Iraq:0.513, Malaysia:0.569, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 126 samples
# [FL-MACRO]   Macro-EER: 0.0215
# [FL-PATIENCE]   No improvement. bad_rounds=4/150
# [FL] ==== [FL] Round 19/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.1991
# [FL-CLIENT] Client China: avg_loss=0.2652
# [FL-CLIENT] Client Czech: avg_loss=0.2535
# [FL-CLIENT] Client India: avg_loss=0.1209
# [FL-CLIENT] Client Iraq: avg_loss=0.1777
# [FL-CLIENT] Client Malaysia: avg_loss=0.4213
# [FL-CLIENT] Client Iran: avg_loss=0.4626
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1638, China:0.1588, Czech:0.1317, India:0.1602, Iraq:0.1295, Malaysia:0.1267, Iran:0.1293
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0169, TAR@1%=0.9722, TAR@0.1%=0.8588
# [FL-METRIC]   China: EER=0.0297, TAR@1%=0.9370, TAR@0.1%=0.7491
# [FL-METRIC]   Czech: EER=0.0034, TAR@1%=1.0000, TAR@0.1%=0.9722
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9760
# [FL-METRIC]   Iraq: EER=0.0249, TAR@1%=0.9100, TAR@0.1%=0.8600
# [FL-METRIC]   Malaysia: EER=0.0178, TAR@1%=0.9000, TAR@0.1%=0.7556
# [FL-METRIC]   Iran: EER=0.0397, TAR@1%=0.8882, TAR@0.1%=0.7702
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.628, China:0.274, Czech:1.000, India:0.828, Iraq:0.407, Malaysia:0.603, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 133 samples
# [FL-MACRO]   Macro-EER: 0.0203
# [FL-BEST]   ✅ New best macro-EER 0.0203 at round 19
# [FL] ==== [FL] Round 20/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.1608
# [FL-CLIENT] Client China: avg_loss=0.2823
# [FL-CLIENT] Client Czech: avg_loss=0.2419
# [FL-CLIENT] Client India: avg_loss=0.1057
# [FL-CLIENT] Client Iraq: avg_loss=0.1600
# [FL-CLIENT] Client Malaysia: avg_loss=0.4093
# [FL-CLIENT] Client Iran: avg_loss=0.4898
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1643, China:0.1560, Czech:0.1324, India:0.1609, Iraq:0.1286, Malaysia:0.1278, Iran:0.1299
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0150, TAR@1%=0.9815, TAR@0.1%=0.8681
# [FL-METRIC]   China: EER=0.0271, TAR@1%=0.9429, TAR@0.1%=0.8002
# [FL-METRIC]   Czech: EER=0.0034, TAR@1%=1.0000, TAR@0.1%=0.9722
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9688
# [FL-METRIC]   Iraq: EER=0.0196, TAR@1%=0.9500, TAR@0.1%=0.9000
# [FL-METRIC]   Malaysia: EER=0.0278, TAR@1%=0.7556, TAR@0.1%=0.5667
# [FL-METRIC]   Iran: EER=0.0373, TAR@1%=0.9006, TAR@0.1%=0.7888
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.658, China:0.300, Czech:1.000, India:0.816, Iraq:0.522, Malaysia:0.280, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 140 samples
# [FL-MACRO]   Macro-EER: 0.0200
# [FL-BEST]   ✅ New best macro-EER 0.0200 at round 20
# [FL] ==== [FL] Round 21/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.1856
# [FL-CLIENT] Client China: avg_loss=0.2583
# [FL-CLIENT] Client Czech: avg_loss=0.2681
# [FL-CLIENT] Client India: avg_loss=0.1170
# [FL-CLIENT] Client Iraq: avg_loss=0.1031
# [FL-CLIENT] Client Malaysia: avg_loss=0.3056
# [FL-CLIENT] Client Iran: avg_loss=0.4158
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1651, China:0.1567, Czech:0.1327, India:0.1611, Iraq:0.1305, Malaysia:0.1235, Iran:0.1302
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0116, TAR@1%=0.9838, TAR@0.1%=0.8611
# [FL-METRIC]   China: EER=0.0255, TAR@1%=0.9465, TAR@0.1%=0.7669
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9880
# [FL-METRIC]   Iraq: EER=0.0240, TAR@1%=0.9100, TAR@0.1%=0.8700
# [FL-METRIC]   Malaysia: EER=0.0222, TAR@1%=0.7667, TAR@0.1%=0.4556
# [FL-METRIC]   Iran: EER=0.0383, TAR@1%=0.9006, TAR@0.1%=0.8137
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.698, China:0.334, Czech:1.000, India:0.749, Iraq:0.374, Malaysia:0.420, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 147 samples
# [FL-MACRO]   Macro-EER: 0.0188
# [FL-BEST]   ✅ New best macro-EER 0.0188 at round 21
# [FL] ==== [FL] Round 22/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.1523
# [FL-CLIENT] Client China: avg_loss=0.2741
# [FL-CLIENT] Client Czech: avg_loss=0.1629
# [FL-CLIENT] Client India: avg_loss=0.1035
# [FL-CLIENT] Client Iraq: avg_loss=0.1475
# [FL-CLIENT] Client Malaysia: avg_loss=0.2804
# [FL-CLIENT] Client Iran: avg_loss=0.3733
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1657, China:0.1572, Czech:0.1327, India:0.1602, Iraq:0.1284, Malaysia:0.1255, Iran:0.1302
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0139, TAR@1%=0.9792, TAR@0.1%=0.8565
# [FL-METRIC]   China: EER=0.0250, TAR@1%=0.9417, TAR@0.1%=0.7955
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9880
# [FL-METRIC]   Iraq: EER=0.0249, TAR@1%=0.9200, TAR@0.1%=0.8900
# [FL-METRIC]   Malaysia: EER=0.0256, TAR@1%=0.8444, TAR@0.1%=0.4444
# [FL-METRIC]   Iran: EER=0.0427, TAR@1%=0.8696, TAR@0.1%=0.7453
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.675, China:0.415, Czech:1.000, India:0.775, Iraq:0.417, Malaysia:0.401, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 154 samples
# [FL-MACRO]   Macro-EER: 0.0202
# [FL-PATIENCE]   No improvement. bad_rounds=1/150
# [FL] ==== [FL] Round 23/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.1554
# [FL-CLIENT] Client China: avg_loss=0.2084
# [FL-CLIENT] Client Czech: avg_loss=0.1968
# [FL-CLIENT] Client India: avg_loss=0.1089
# [FL-CLIENT] Client Iraq: avg_loss=0.1329
# [FL-CLIENT] Client Malaysia: avg_loss=0.2950
# [FL-CLIENT] Client Iran: avg_loss=0.2883
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1651, China:0.1581, Czech:0.1325, India:0.1603, Iraq:0.1289, Malaysia:0.1251, Iran:0.1300
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0139, TAR@1%=0.9838, TAR@0.1%=0.8727
# [FL-METRIC]   China: EER=0.0178, TAR@1%=0.9631, TAR@0.1%=0.7634
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9784
# [FL-METRIC]   Iraq: EER=0.0213, TAR@1%=0.9300, TAR@0.1%=0.9100
# [FL-METRIC]   Malaysia: EER=0.0244, TAR@1%=0.7889, TAR@0.1%=0.3778
# [FL-METRIC]   Iran: EER=0.0383, TAR@1%=0.9006, TAR@0.1%=0.8012
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.638, China:0.535, Czech:1.000, India:0.749, Iraq:0.444, Malaysia:0.363, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 161 samples
# [FL-MACRO]   Macro-EER: 0.0179
# [FL-BEST]   ✅ New best macro-EER 0.0179 at round 23
# [FL] ==== [FL] Round 24/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.1517
# [FL-CLIENT] Client China: avg_loss=0.2300
# [FL-CLIENT] Client Czech: avg_loss=0.1654
# [FL-CLIENT] Client India: avg_loss=0.0750
# [FL-CLIENT] Client Iraq: avg_loss=0.1402
# [FL-CLIENT] Client Malaysia: avg_loss=0.3011
# [FL-CLIENT] Client Iran: avg_loss=0.4028
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1645, China:0.1597, Czech:0.1324, India:0.1599, Iraq:0.1291, Malaysia:0.1244, Iran:0.1299
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0161, TAR@1%=0.9815, TAR@0.1%=0.8773
# [FL-METRIC]   China: EER=0.0250, TAR@1%=0.9453, TAR@0.1%=0.7979
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0072, TAR@1%=0.9928, TAR@0.1%=0.9832
# [FL-METRIC]   Iraq: EER=0.0213, TAR@1%=0.9100, TAR@0.1%=0.8900
# [FL-METRIC]   Malaysia: EER=0.0244, TAR@1%=0.7667, TAR@0.1%=0.4111
# [FL-METRIC]   Iran: EER=0.0435, TAR@1%=0.8634, TAR@0.1%=0.7950
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.629, China:0.426, Czech:1.000, India:0.834, Iraq:0.509, Malaysia:0.438, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 168 samples
# [FL-MACRO]   Macro-EER: 0.0197
# [FL-PATIENCE]   No improvement. bad_rounds=1/150
# [FL] ==== [FL] Round 25/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.1291
# [FL-CLIENT] Client China: avg_loss=0.2221
# [FL-CLIENT] Client Czech: avg_loss=0.1614
# [FL-CLIENT] Client India: avg_loss=0.1120
# [FL-CLIENT] Client Iraq: avg_loss=0.0845
# [FL-CLIENT] Client Malaysia: avg_loss=0.4152
# [FL-CLIENT] Client Iran: avg_loss=0.4302
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1641, China:0.1579, Czech:0.1322, India:0.1608, Iraq:0.1299, Malaysia:0.1253, Iran:0.1297
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0116, TAR@1%=0.9861, TAR@0.1%=0.8912
# [FL-METRIC]   China: EER=0.0297, TAR@1%=0.9405, TAR@0.1%=0.8181
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9808
# [FL-METRIC]   Iraq: EER=0.0200, TAR@1%=0.9400, TAR@0.1%=0.9100
# [FL-METRIC]   Malaysia: EER=0.0278, TAR@1%=0.7889, TAR@0.1%=0.5778
# [FL-METRIC]   Iran: EER=0.0423, TAR@1%=0.8820, TAR@0.1%=0.7453
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.727, China:0.298, Czech:1.000, India:0.773, Iraq:0.528, Malaysia:0.344, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 175 samples
# [FL-MACRO]   Macro-EER: 0.0201
# [FL-PATIENCE]   No improvement. bad_rounds=2/150
# [FL] ==== [FL] Round 26/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.1548
# [FL-CLIENT] Client China: avg_loss=0.2178
# [FL-CLIENT] Client Czech: avg_loss=0.1307
# [FL-CLIENT] Client India: avg_loss=0.0843
# [FL-CLIENT] Client Iraq: avg_loss=0.1591
# [FL-CLIENT] Client Malaysia: avg_loss=0.3897
# [FL-CLIENT] Client Iran: avg_loss=0.4033
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1659, China:0.1565, Czech:0.1325, India:0.1603, Iraq:0.1304, Malaysia:0.1243, Iran:0.1300
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0116, TAR@1%=0.9838, TAR@0.1%=0.8773
# [FL-METRIC]   China: EER=0.0297, TAR@1%=0.9477, TAR@0.1%=0.8216
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9832
# [FL-METRIC]   Iraq: EER=0.0187, TAR@1%=0.9600, TAR@0.1%=0.9300
# [FL-METRIC]   Malaysia: EER=0.0233, TAR@1%=0.7667, TAR@0.1%=0.4222
# [FL-METRIC]   Iran: EER=0.0397, TAR@1%=0.8882, TAR@0.1%=0.8261
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.708, China:0.251, Czech:1.000, India:0.758, Iraq:0.530, Malaysia:0.412, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 182 samples
# [FL-MACRO]   Macro-EER: 0.0189
# [FL-PATIENCE]   No improvement. bad_rounds=3/150
# [FL] ==== [FL] Round 27/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.1081
# [FL-CLIENT] Client China: avg_loss=0.2515
# [FL-CLIENT] Client Czech: avg_loss=0.1184
# [FL-CLIENT] Client India: avg_loss=0.0823
# [FL-CLIENT] Client Iraq: avg_loss=0.1011
# [FL-CLIENT] Client Malaysia: avg_loss=0.3732
# [FL-CLIENT] Client Iran: avg_loss=0.3483
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1656, China:0.1559, Czech:0.1325, India:0.1602, Iraq:0.1305, Malaysia:0.1252, Iran:0.1301
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0116, TAR@1%=0.9838, TAR@0.1%=0.8866
# [FL-METRIC]   China: EER=0.0224, TAR@1%=0.9465, TAR@0.1%=0.7872
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9832
# [FL-METRIC]   Iraq: EER=0.0151, TAR@1%=0.9700, TAR@0.1%=0.9100
# [FL-METRIC]   Malaysia: EER=0.0222, TAR@1%=0.9000, TAR@0.1%=0.6667
# [FL-METRIC]   Iran: EER=0.0373, TAR@1%=0.8944, TAR@0.1%=0.8447
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.689, China:0.400, Czech:1.000, India:0.742, Iraq:0.595, Malaysia:0.404, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 189 samples
# [FL-MACRO]   Macro-EER: 0.0169
# [FL-BEST]   ✅ New best macro-EER 0.0169 at round 27
# [FL] ==== [FL] Round 28/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.1105
# [FL-CLIENT] Client China: avg_loss=0.2859
# [FL-CLIENT] Client Czech: avg_loss=0.2644
# [FL-CLIENT] Client India: avg_loss=0.0885
# [FL-CLIENT] Client Iraq: avg_loss=0.1907
# [FL-CLIENT] Client Malaysia: avg_loss=0.2318
# [FL-CLIENT] Client Iran: avg_loss=0.3620
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1650, China:0.1576, Czech:0.1322, India:0.1596, Iraq:0.1311, Malaysia:0.1248, Iran:0.1298
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0139, TAR@1%=0.9792, TAR@0.1%=0.8796
# [FL-METRIC]   China: EER=0.0194, TAR@1%=0.9596, TAR@0.1%=0.8300
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0086, TAR@1%=0.9928, TAR@0.1%=0.9808
# [FL-METRIC]   Iraq: EER=0.0151, TAR@1%=0.9800, TAR@0.1%=0.9100
# [FL-METRIC]   Malaysia: EER=0.0222, TAR@1%=0.8333, TAR@0.1%=0.6444
# [FL-METRIC]   Iran: EER=0.0311, TAR@1%=0.9006, TAR@0.1%=0.8137
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.553, China:0.374, Czech:1.000, India:0.724, Iraq:0.513, Malaysia:0.284, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 196 samples
# [FL-MACRO]   Macro-EER: 0.0158
# [FL-BEST]   ✅ New best macro-EER 0.0158 at round 28
# [FL] ==== [FL] Round 29/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.1105
# [FL-CLIENT] Client China: avg_loss=0.1704
# [FL-CLIENT] Client Czech: avg_loss=0.1383
# [FL-CLIENT] Client India: avg_loss=0.0771
# [FL-CLIENT] Client Iraq: avg_loss=0.0774
# [FL-CLIENT] Client Malaysia: avg_loss=0.1390
# [FL-CLIENT] Client Iran: avg_loss=0.3033
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1640, China:0.1581, Czech:0.1329, India:0.1601, Iraq:0.1306, Malaysia:0.1238, Iran:0.1304
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0108, TAR@1%=0.9838, TAR@0.1%=0.9005
# [FL-METRIC]   China: EER=0.0214, TAR@1%=0.9572, TAR@0.1%=0.8585
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0092, TAR@1%=0.9928, TAR@0.1%=0.9808
# [FL-METRIC]   Iraq: EER=0.0222, TAR@1%=0.8900, TAR@0.1%=0.8700
# [FL-METRIC]   Malaysia: EER=0.0222, TAR@1%=0.8333, TAR@0.1%=0.5333
# [FL-METRIC]   Iran: EER=0.0317, TAR@1%=0.8758, TAR@0.1%=0.7888
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.659, China:0.324, Czech:1.000, India:0.710, Iraq:0.298, Malaysia:0.298, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 203 samples
# [FL-MACRO]   Macro-EER: 0.0168
# [FL-PATIENCE]   No improvement. bad_rounds=1/150
# [FL] ==== [FL] Round 30/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.1013
# [FL-CLIENT] Client China: avg_loss=0.1832
# [FL-CLIENT] Client Czech: avg_loss=0.1949
# [FL-CLIENT] Client India: avg_loss=0.0756
# [FL-CLIENT] Client Iraq: avg_loss=0.1402
# [FL-CLIENT] Client Malaysia: avg_loss=0.2823
# [FL-CLIENT] Client Iran: avg_loss=0.3262
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1658, China:0.1577, Czech:0.1332, India:0.1603, Iraq:0.1279, Malaysia:0.1243, Iran:0.1307
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0131, TAR@1%=0.9838, TAR@0.1%=0.8935
# [FL-METRIC]   China: EER=0.0214, TAR@1%=0.9548, TAR@0.1%=0.8490
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9808
# [FL-METRIC]   Iraq: EER=0.0222, TAR@1%=0.9000, TAR@0.1%=0.8800
# [FL-METRIC]   Malaysia: EER=0.0189, TAR@1%=0.8889, TAR@0.1%=0.5889
# [FL-METRIC]   Iran: EER=0.0287, TAR@1%=0.8758, TAR@0.1%=0.7578
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.545, China:0.254, Czech:1.000, India:0.665, Iraq:0.225, Malaysia:0.341, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 210 samples
# [FL-MACRO]   Macro-EER: 0.0163
# [FL-PATIENCE]   No improvement. bad_rounds=2/150
# [FL] ==== [FL] Round 31/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.1328
# [FL-CLIENT] Client China: avg_loss=0.2263
# [FL-CLIENT] Client Czech: avg_loss=0.1932
# [FL-CLIENT] Client India: avg_loss=0.0760
# [FL-CLIENT] Client Iraq: avg_loss=0.1492
# [FL-CLIENT] Client Malaysia: avg_loss=0.2718
# [FL-CLIENT] Client Iran: avg_loss=0.2909
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1648, China:0.1573, Czech:0.1337, India:0.1603, Iraq:0.1273, Malaysia:0.1254, Iran:0.1312
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0095, TAR@1%=0.9931, TAR@0.1%=0.8750
# [FL-METRIC]   China: EER=0.0186, TAR@1%=0.9631, TAR@0.1%=0.8216
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9736
# [FL-METRIC]   Iraq: EER=0.0222, TAR@1%=0.9100, TAR@0.1%=0.9000
# [FL-METRIC]   Malaysia: EER=0.0167, TAR@1%=0.9444, TAR@0.1%=0.7889
# [FL-METRIC]   Iran: EER=0.0320, TAR@1%=0.9255, TAR@0.1%=0.8634
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.704, China:0.419, Czech:1.000, India:0.700, Iraq:0.306, Malaysia:0.479, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 217 samples
# [FL-MACRO]   Macro-EER: 0.0155
# [FL-BEST]   ✅ New best macro-EER 0.0155 at round 31
# [FL] ==== [FL] Round 32/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.1151
# [FL-CLIENT] Client China: avg_loss=0.1922
# [FL-CLIENT] Client Czech: avg_loss=0.1606
# [FL-CLIENT] Client India: avg_loss=0.0741
# [FL-CLIENT] Client Iraq: avg_loss=0.0841
# [FL-CLIENT] Client Malaysia: avg_loss=0.2263
# [FL-CLIENT] Client Iran: avg_loss=0.3216
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1657, China:0.1583, Czech:0.1326, India:0.1595, Iraq:0.1274, Malaysia:0.1263, Iran:0.1302
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0117, TAR@1%=0.9861, TAR@0.1%=0.8866
# [FL-METRIC]   China: EER=0.0247, TAR@1%=0.9572, TAR@0.1%=0.8680
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0085, TAR@1%=0.9928, TAR@0.1%=0.9856
# [FL-METRIC]   Iraq: EER=0.0107, TAR@1%=0.9800, TAR@0.1%=0.9400
# [FL-METRIC]   Malaysia: EER=0.0178, TAR@1%=0.9111, TAR@0.1%=0.7000
# [FL-METRIC]   Iran: EER=0.0250, TAR@1%=0.9255, TAR@0.1%=0.8012
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.533, China:0.012, Czech:1.000, India:0.659, Iraq:0.573, Malaysia:0.289, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 224 samples
# [FL-MACRO]   Macro-EER: 0.0141
# [FL-BEST]   ✅ New best macro-EER 0.0141 at round 32
# [FL] ==== [FL] Round 33/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.0904
# [FL-CLIENT] Client China: avg_loss=0.1619
# [FL-CLIENT] Client Czech: avg_loss=0.1433
# [FL-CLIENT] Client India: avg_loss=0.0556
# [FL-CLIENT] Client Iraq: avg_loss=0.0755
# [FL-CLIENT] Client Malaysia: avg_loss=0.2577
# [FL-CLIENT] Client Iran: avg_loss=0.2401
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1646, China:0.1538, Czech:0.1336, India:0.1601, Iraq:0.1322, Malaysia:0.1246, Iran:0.1311
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0108, TAR@1%=0.9838, TAR@0.1%=0.8819
# [FL-METRIC]   China: EER=0.0218, TAR@1%=0.9584, TAR@0.1%=0.8621
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0072, TAR@1%=0.9928, TAR@0.1%=0.9880
# [FL-METRIC]   Iraq: EER=0.0142, TAR@1%=0.9700, TAR@0.1%=0.9300
# [FL-METRIC]   Malaysia: EER=0.0222, TAR@1%=0.9000, TAR@0.1%=0.7333
# [FL-METRIC]   Iran: EER=0.0303, TAR@1%=0.9317, TAR@0.1%=0.8075
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.645, China:0.282, Czech:1.000, India:0.762, Iraq:0.531, Malaysia:0.268, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 231 samples
# [FL-MACRO]   Macro-EER: 0.0152
# [FL-PATIENCE]   No improvement. bad_rounds=1/150
# [FL] ==== [FL] Round 34/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.1293
# [FL-CLIENT] Client China: avg_loss=0.2589
# [FL-CLIENT] Client Czech: avg_loss=0.1619
# [FL-CLIENT] Client India: avg_loss=0.0727
# [FL-CLIENT] Client Iraq: avg_loss=0.1531
# [FL-CLIENT] Client Malaysia: avg_loss=0.2872
# [FL-CLIENT] Client Iran: avg_loss=0.3796
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1652, China:0.1567, Czech:0.1329, India:0.1606, Iraq:0.1308, Malaysia:0.1235, Iran:0.1304
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0086, TAR@1%=0.9954, TAR@0.1%=0.8843
# [FL-METRIC]   China: EER=0.0238, TAR@1%=0.9596, TAR@0.1%=0.8419
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0086, TAR@1%=0.9928, TAR@0.1%=0.9880
# [FL-METRIC]   Iraq: EER=0.0204, TAR@1%=0.9300, TAR@0.1%=0.9100
# [FL-METRIC]   Malaysia: EER=0.0211, TAR@1%=0.9444, TAR@0.1%=0.7111
# [FL-METRIC]   Iran: EER=0.0311, TAR@1%=0.9255, TAR@0.1%=0.8447
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.723, China:0.234, Czech:1.000, India:0.722, Iraq:0.342, Malaysia:0.320, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 238 samples
# [FL-MACRO]   Macro-EER: 0.0162
# [FL-PATIENCE]   No improvement. bad_rounds=2/150
# [FL] ==== [FL] Round 35/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.0911
# [FL-CLIENT] Client China: avg_loss=0.1597
# [FL-CLIENT] Client Czech: avg_loss=0.1454
# [FL-CLIENT] Client India: avg_loss=0.0657
# [FL-CLIENT] Client Iraq: avg_loss=0.0806
# [FL-CLIENT] Client Malaysia: avg_loss=0.2602
# [FL-CLIENT] Client Iran: avg_loss=0.3478
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1666, China:0.1563, Czech:0.1331, India:0.1604, Iraq:0.1284, Malaysia:0.1245, Iran:0.1306
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0090, TAR@1%=0.9931, TAR@0.1%=0.8958
# [FL-METRIC]   China: EER=0.0213, TAR@1%=0.9655, TAR@0.1%=0.8561
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0089, TAR@1%=0.9928, TAR@0.1%=0.9904
# [FL-METRIC]   Iraq: EER=0.0100, TAR@1%=0.9900, TAR@0.1%=0.9600
# [FL-METRIC]   Malaysia: EER=0.0311, TAR@1%=0.8333, TAR@0.1%=0.6000
# [FL-METRIC]   Iran: EER=0.0313, TAR@1%=0.9193, TAR@0.1%=0.7950
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.711, China:0.321, Czech:1.000, India:0.716, Iraq:0.681, Malaysia:0.007, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 245 samples
# [FL-MACRO]   Macro-EER: 0.0160
# [FL-PATIENCE]   No improvement. bad_rounds=3/150
# [FL] ==== [FL] Round 36/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.1314
# [FL-CLIENT] Client China: avg_loss=0.2090
# [FL-CLIENT] Client Czech: avg_loss=0.1472
# [FL-CLIENT] Client India: avg_loss=0.0749
# [FL-CLIENT] Client Iraq: avg_loss=0.0963
# [FL-CLIENT] Client Malaysia: avg_loss=0.2790
# [FL-CLIENT] Client Iran: avg_loss=0.2483
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1662, China:0.1573, Czech:0.1330, India:0.1601, Iraq:0.1330, Malaysia:0.1200, Iran:0.1305
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0116, TAR@1%=0.9861, TAR@0.1%=0.8889
# [FL-METRIC]   China: EER=0.0238, TAR@1%=0.9572, TAR@0.1%=0.8621
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9880
# [FL-METRIC]   Iraq: EER=0.0100, TAR@1%=0.9900, TAR@0.1%=0.9400
# [FL-METRIC]   Malaysia: EER=0.0222, TAR@1%=0.9000, TAR@0.1%=0.7444
# [FL-METRIC]   Iran: EER=0.0380, TAR@1%=0.9255, TAR@0.1%=0.7702
# [FL-Q] Quality Q_k (warmup OG): Pakistan:0.696, China:0.374, Czech:1.000, India:0.747, Iraq:0.737, Malaysia:0.415, Iran:0.000
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 252 samples
# [FL-MACRO]   Macro-EER: 0.0165
# [FL-PATIENCE]   No improvement. bad_rounds=4/150
# [FL] ==== [FL] Round 37/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.0928
# [FL-CLIENT] Client China: avg_loss=0.1875
# [FL-CLIENT] Client Czech: avg_loss=0.1452
# [FL-CLIENT] Client India: avg_loss=0.0582
# [FL-CLIENT] Client Iraq: avg_loss=0.0662
# [FL-CLIENT] Client Malaysia: avg_loss=0.1643
# [FL-CLIENT] Client Iran: avg_loss=0.3794
# [FL-WEIGHTS] FHIR weights (WARMUP-OG): Pakistan:0.1648, China:0.1569, Czech:0.1320, India:0.1593, Iraq:0.1328, Malaysia:0.1248, Iran:0.1295
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0079, TAR@1%=0.9954, TAR@0.1%=0.8727
# [FL-METRIC]   China: EER=0.0214, TAR@1%=0.9584, TAR@0.1%=0.8644
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0076, TAR@1%=0.9928, TAR@0.1%=0.9856
# ...
# [FL-POLY] POLY buffer size: 1680 samples
# [FL-POLY] POLY model: fitted/updated (scaled -> degree-2 poly -> ridge).
# [FL-POLY] POLY score s_k: Pakistan:0.6937, China:0.6933, Czech:0.6932, India:0.6933, Iraq:0.6933, Malaysia:0.6937, Iran:0.6947
# [FL-POLY] weights_next_round: Pakistan:0.1429, China:0.1428, Czech:0.1428, India:0.1428, Iraq:0.1428, Malaysia:0.1429, Iran:0.1431
# [FL-MACRO]   Macro-EER: 0.0060
# [FL-PATIENCE]   No improvement. bad_rounds=36/150
# [FL] ==== [FL] Round 241/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.0141
# [FL-CLIENT] Client China: avg_loss=0.0148
# [FL-CLIENT] Client Czech: avg_loss=0.0039
# [FL-CLIENT] Client India: avg_loss=0.0088
# [FL-CLIENT] Client Iraq: avg_loss=0.0067
# [FL-CLIENT] Client Malaysia: avg_loss=0.0102
# [FL-CLIENT] Client Iran: avg_loss=0.0164
# [FL-WEIGHTS] FHIR weights (POLY, from prev eval): Pakistan:0.1429, China:0.1428, Czech:0.1428, India:0.1428, Iraq:0.1428, Malaysia:0.1429, Iran:0.1431
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0066, TAR@1%=0.9954, TAR@0.1%=0.9676
# [FL-METRIC]   China: EER=0.0071, TAR@1%=0.9952, TAR@0.1%=0.9774
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0072, TAR@1%=0.9928, TAR@0.1%=0.9808
# [FL-METRIC]   Iraq: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   Malaysia: EER=0.0011, TAR@1%=1.0000, TAR@0.1%=0.9778
# [FL-METRIC]   Iran: EER=0.0143, TAR@1%=0.9565, TAR@0.1%=0.8634
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 1687 samples
# [FL-POLY] POLY model: fitted/updated (scaled -> degree-2 poly -> ridge).
# [FL-POLY] POLY score s_k: Pakistan:0.6935, China:0.6933, Czech:0.6932, India:0.6932, Iraq:0.6933, Malaysia:0.6937, Iran:0.6943
# [FL-POLY] weights_next_round: Pakistan:0.1429, China:0.1428, Czech:0.1428, India:0.1428, Iraq:0.1428, Malaysia:0.1429, Iran:0.1430
# [FL-MACRO]   Macro-EER: 0.0052
# [FL-PATIENCE]   No improvement. bad_rounds=37/150
# [FL] ==== [FL] Round 242/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.0146
# [FL-CLIENT] Client China: avg_loss=0.0080
# [FL-CLIENT] Client Czech: avg_loss=0.0029
# [FL-CLIENT] Client India: avg_loss=0.0049
# [FL-CLIENT] Client Iraq: avg_loss=0.0020
# [FL-CLIENT] Client Malaysia: avg_loss=0.0056
# [FL-CLIENT] Client Iran: avg_loss=0.0106
# [FL-WEIGHTS] FHIR weights (POLY, from prev eval): Pakistan:0.1429, China:0.1428, Czech:0.1428, India:0.1428, Iraq:0.1428, Malaysia:0.1429, Iran:0.1430
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0053, TAR@1%=0.9954, TAR@0.1%=0.9676
# [FL-METRIC]   China: EER=0.0071, TAR@1%=0.9941, TAR@0.1%=0.9786
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0072, TAR@1%=0.9928, TAR@0.1%=0.9856
# [FL-METRIC]   Iraq: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   Malaysia: EER=0.0022, TAR@1%=1.0000, TAR@0.1%=0.9444
# [FL-METRIC]   Iran: EER=0.0186, TAR@1%=0.9565, TAR@0.1%=0.8571
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 1694 samples
# [FL-POLY] POLY model: fitted/updated (scaled -> degree-2 poly -> ridge).
# [FL-POLY] POLY score s_k: Pakistan:0.6936, China:0.6935, Czech:0.6932, India:0.6933, Iraq:0.6933, Malaysia:0.6939, Iran:0.6945
# [FL-POLY] weights_next_round: Pakistan:0.1429, China:0.1428, Czech:0.1428, India:0.1428, Iraq:0.1428, Malaysia:0.1429, Iran:0.1430
# [FL-MACRO]   Macro-EER: 0.0058
# [FL-PATIENCE]   No improvement. bad_rounds=38/150
# [FL] ==== [FL] Round 243/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.0042
# [FL-CLIENT] Client China: avg_loss=0.0118
# [FL-CLIENT] Client Czech: avg_loss=0.0030
# [FL-CLIENT] Client India: avg_loss=0.0022
# [FL-CLIENT] Client Iraq: avg_loss=0.0009
# [FL-CLIENT] Client Malaysia: avg_loss=0.0049
# [FL-CLIENT] Client Iran: avg_loss=0.0281
# [FL-WEIGHTS] FHIR weights (POLY, from prev eval): Pakistan:0.1429, China:0.1428, Czech:0.1428, India:0.1428, Iraq:0.1428, Malaysia:0.1429, Iran:0.1430
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0057, TAR@1%=0.9954, TAR@0.1%=0.9699
# [FL-METRIC]   China: EER=0.0071, TAR@1%=0.9929, TAR@0.1%=0.9762
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9856
# [FL-METRIC]   Iraq: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   Malaysia: EER=0.0022, TAR@1%=1.0000, TAR@0.1%=0.9444
# [FL-METRIC]   Iran: EER=0.0210, TAR@1%=0.9627, TAR@0.1%=0.8447
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 1701 samples
# [FL-POLY] POLY model: fitted/updated (scaled -> degree-2 poly -> ridge).
# [FL-POLY] POLY score s_k: Pakistan:0.6936, China:0.6936, Czech:0.6932, India:0.6935, Iraq:0.6933, Malaysia:0.6939, Iran:0.6942
# [FL-POLY] weights_next_round: Pakistan:0.1429, China:0.1428, Czech:0.1428, India:0.1428, Iraq:0.1428, Malaysia:0.1429, Iran:0.1430
# [FL-MACRO]   Macro-EER: 0.0065
# [FL-PATIENCE]   No improvement. bad_rounds=39/150
# [FL] ==== [FL] Round 244/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.0110
# [FL-CLIENT] Client China: avg_loss=0.0175
# [FL-CLIENT] Client Czech: avg_loss=0.0033
# [FL-CLIENT] Client India: avg_loss=0.0082
# [FL-CLIENT] Client Iraq: avg_loss=0.0011
# [FL-CLIENT] Client Malaysia: avg_loss=0.0038
# [FL-CLIENT] Client Iran: avg_loss=0.0250
# [FL-WEIGHTS] FHIR weights (POLY, from prev eval): Pakistan:0.1429, China:0.1428, Czech:0.1428, India:0.1428, Iraq:0.1428, Malaysia:0.1429, Iran:0.1430
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0046, TAR@1%=0.9977, TAR@0.1%=0.9722
# [FL-METRIC]   China: EER=0.0072, TAR@1%=0.9952, TAR@0.1%=0.9822
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9880
# [FL-METRIC]   Iraq: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   Malaysia: EER=0.0022, TAR@1%=1.0000, TAR@0.1%=0.9889
# [FL-METRIC]   Iran: EER=0.0147, TAR@1%=0.9627, TAR@0.1%=0.8571
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 1708 samples
# [FL-POLY] POLY model: fitted/updated (scaled -> degree-2 poly -> ridge).
# [FL-POLY] POLY score s_k: Pakistan:0.6933, China:0.6934, Czech:0.6932, India:0.6935, Iraq:0.6933, Malaysia:0.6938, Iran:0.6941
# [FL-POLY] weights_next_round: Pakistan:0.1428, China:0.1428, Czech:0.1428, India:0.1429, Iraq:0.1428, Malaysia:0.1429, Iran:0.1430
# [FL-MACRO]   Macro-EER: 0.0055
# [FL-PATIENCE]   No improvement. bad_rounds=40/150
# [FL] ==== [FL] Round 245/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.0105
# [FL-CLIENT] Client China: avg_loss=0.0157
# [FL-CLIENT] Client Czech: avg_loss=0.0031
# [FL-CLIENT] Client India: avg_loss=0.0020
# [FL-CLIENT] Client Iraq: avg_loss=0.0021
# [FL-CLIENT] Client Malaysia: avg_loss=0.0048
# [FL-CLIENT] Client Iran: avg_loss=0.0194
# [FL-WEIGHTS] FHIR weights (POLY, from prev eval): Pakistan:0.1428, China:0.1428, Czech:0.1428, India:0.1429, Iraq:0.1428, Malaysia:0.1429, Iran:0.1430
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0069, TAR@1%=0.9954, TAR@0.1%=0.9745
# [FL-METRIC]   China: EER=0.0083, TAR@1%=0.9929, TAR@0.1%=0.9620
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0096, TAR@1%=0.9904, TAR@0.1%=0.9856
# [FL-METRIC]   Iraq: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   Malaysia: EER=0.0011, TAR@1%=1.0000, TAR@0.1%=0.9778
# [FL-METRIC]   Iran: EER=0.0180, TAR@1%=0.9627, TAR@0.1%=0.8571
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 1715 samples
# [FL-POLY] POLY model: fitted/updated (scaled -> degree-2 poly -> ridge).
# [FL-POLY] POLY score s_k: Pakistan:0.6936, China:0.6932, Czech:0.6932, India:0.6934, Iraq:0.6933, Malaysia:0.6937, Iran:0.6942
# [FL-POLY] weights_next_round: Pakistan:0.1429, China:0.1428, Czech:0.1428, India:0.1428, Iraq:0.1428, Malaysia:0.1429, Iran:0.1430
# [FL-MACRO]   Macro-EER: 0.0063
# [FL-PATIENCE]   No improvement. bad_rounds=41/150
# [FL] ==== [FL] Round 246/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.0078
# [FL-CLIENT] Client China: avg_loss=0.0181
# [FL-CLIENT] Client Czech: avg_loss=0.0098
# [FL-CLIENT] Client India: avg_loss=0.0052
# [FL-CLIENT] Client Iraq: avg_loss=0.0061
# [FL-CLIENT] Client Malaysia: avg_loss=0.0090
# [FL-CLIENT] Client Iran: avg_loss=0.0542
# [FL-WEIGHTS] FHIR weights (POLY, from prev eval): Pakistan:0.1429, China:0.1428, Czech:0.1428, India:0.1428, Iraq:0.1428, Malaysia:0.1429, Iran:0.1430
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0069, TAR@1%=0.9954, TAR@0.1%=0.9722
# [FL-METRIC]   China: EER=0.0077, TAR@1%=0.9941, TAR@0.1%=0.9560
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0072, TAR@1%=0.9928, TAR@0.1%=0.9880
# [FL-METRIC]   Iraq: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   Malaysia: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   Iran: EER=0.0124, TAR@1%=0.9752, TAR@0.1%=0.8696
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 1722 samples
# [FL-POLY] POLY model: fitted/updated (scaled -> degree-2 poly -> ridge).
# [FL-POLY] POLY score s_k: Pakistan:0.6936, China:0.6930, Czech:0.6932, India:0.6933, Iraq:0.6933, Malaysia:0.6935, Iran:0.6937
# [FL-POLY] weights_next_round: Pakistan:0.1429, China:0.1428, Czech:0.1428, India:0.1428, Iraq:0.1428, Malaysia:0.1429, Iran:0.1429
# [FL-MACRO]   Macro-EER: 0.0049
# [FL-PATIENCE]   No improvement. bad_rounds=42/150
# [FL] ==== [FL] Round 247/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.0127
# [FL-CLIENT] Client China: avg_loss=0.0166
# [FL-CLIENT] Client Czech: avg_loss=0.0041
# [FL-CLIENT] Client India: avg_loss=0.0029
# [FL-CLIENT] Client Iraq: avg_loss=0.0083
# [FL-CLIENT] Client Malaysia: avg_loss=0.0077
# [FL-CLIENT] Client Iran: avg_loss=0.0121
# [FL-WEIGHTS] FHIR weights (POLY, from prev eval): Pakistan:0.1429, China:0.1428, Czech:0.1428, India:0.1428, Iraq:0.1428, Malaysia:0.1429, Iran:0.1429
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0067, TAR@1%=0.9954, TAR@0.1%=0.9653
# [FL-METRIC]   China: EER=0.0071, TAR@1%=0.9952, TAR@0.1%=0.9738
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0072, TAR@1%=0.9928, TAR@0.1%=0.9856
# [FL-METRIC]   Iraq: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   Malaysia: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   Iran: EER=0.0180, TAR@1%=0.9627, TAR@0.1%=0.8820
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 1729 samples
# [FL-POLY] POLY model: fitted/updated (scaled -> degree-2 poly -> ridge).
# [FL-POLY] POLY score s_k: Pakistan:0.6935, China:0.6932, Czech:0.6932, India:0.6933, Iraq:0.6933, Malaysia:0.6935, Iran:0.6944
# [FL-POLY] weights_next_round: Pakistan:0.1429, China:0.1428, Czech:0.1428, India:0.1428, Iraq:0.1428, Malaysia:0.1429, Iran:0.1430
# [FL-MACRO]   Macro-EER: 0.0056
# [FL-PATIENCE]   No improvement. bad_rounds=43/150
# [FL] ==== [FL] Round 248/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.0064
# [FL-CLIENT] Client China: avg_loss=0.0150
# [FL-CLIENT] Client Czech: avg_loss=0.0050
# [FL-CLIENT] Client India: avg_loss=0.0054
# [FL-CLIENT] Client Iraq: avg_loss=0.0019
# [FL-CLIENT] Client Malaysia: avg_loss=0.0094
# [FL-CLIENT] Client Iran: avg_loss=0.0262
# [FL-WEIGHTS] FHIR weights (POLY, from prev eval): Pakistan:0.1429, China:0.1428, Czech:0.1428, India:0.1428, Iraq:0.1428, Malaysia:0.1429, Iran:0.1430
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0069, TAR@1%=0.9954, TAR@0.1%=0.9745
# [FL-METRIC]   China: EER=0.0071, TAR@1%=0.9941, TAR@0.1%=0.9715
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0072, TAR@1%=0.9928, TAR@0.1%=0.9880
# [FL-METRIC]   Iraq: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   Malaysia: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   Iran: EER=0.0143, TAR@1%=0.9627, TAR@0.1%=0.8820
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 1736 samples
# [FL-POLY] POLY model: fitted/updated (scaled -> degree-2 poly -> ridge).
# [FL-POLY] POLY score s_k: Pakistan:0.6936, China:0.6933, Czech:0.6932, India:0.6933, Iraq:0.6933, Malaysia:0.6935, Iran:0.6942
# [FL-POLY] weights_next_round: Pakistan:0.1429, China:0.1428, Czech:0.1428, India:0.1428, Iraq:0.1428, Malaysia:0.1429, Iran:0.1430
# [FL-MACRO]   Macro-EER: 0.0051
# [FL-PATIENCE]   No improvement. bad_rounds=44/150
# [FL] ==== [FL] Round 249/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.0049
# [FL-CLIENT] Client China: avg_loss=0.0129
# [FL-CLIENT] Client Czech: avg_loss=0.0016
# [FL-CLIENT] Client India: avg_loss=0.0030
# [FL-CLIENT] Client Iraq: avg_loss=0.0011
# [FL-CLIENT] Client Malaysia: avg_loss=0.0095
# [FL-CLIENT] Client Iran: avg_loss=0.0380
# [FL-WEIGHTS] FHIR weights (POLY, from prev eval): Pakistan:0.1429, China:0.1428, Czech:0.1428, India:0.1428, Iraq:0.1428, Malaysia:0.1429, Iran:0.1430
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0073, TAR@1%=0.9954, TAR@0.1%=0.9630
# [FL-METRIC]   China: EER=0.0059, TAR@1%=0.9952, TAR@0.1%=0.9727
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0072, TAR@1%=0.9928, TAR@0.1%=0.9904
# [FL-METRIC]   Iraq: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   Malaysia: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   Iran: EER=0.0137, TAR@1%=0.9627, TAR@0.1%=0.8571
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 1743 samples
# [FL-POLY] POLY model: fitted/updated (scaled -> degree-2 poly -> ridge).
# [FL-POLY] POLY score s_k: Pakistan:0.6934, China:0.6934, Czech:0.6932, India:0.6933, Iraq:0.6933, Malaysia:0.6935, Iran:0.6941
# [FL-POLY] weights_next_round: Pakistan:0.1428, China:0.1428, Czech:0.1428, India:0.1428, Iraq:0.1428, Malaysia:0.1429, Iran:0.1430
# [FL-MACRO]   Macro-EER: 0.0049
# [FL-PATIENCE]   No improvement. bad_rounds=45/150
# [FL] ==== [FL] Round 250/250 | strategy=fhir_poly ====
# [FL-CLIENT] Client Pakistan: avg_loss=0.0051
# [FL-CLIENT] Client China: avg_loss=0.0119
# [FL-CLIENT] Client Czech: avg_loss=0.0023
# [FL-CLIENT] Client India: avg_loss=0.0052
# [FL-CLIENT] Client Iraq: avg_loss=0.0023
# [FL-CLIENT] Client Malaysia: avg_loss=0.0257
# [FL-CLIENT] Client Iran: avg_loss=0.0242
# [FL-WEIGHTS] FHIR weights (POLY, from prev eval): Pakistan:0.1428, China:0.1428, Czech:0.1428, India:0.1428, Iraq:0.1428, Malaysia:0.1429, Iran:0.1430
# [FL-EVAL] Evaluating global model on validation splits...
# [FL-METRIC]   Pakistan: EER=0.0074, TAR@1%=0.9954, TAR@0.1%=0.9745
# [FL-METRIC]   China: EER=0.0061, TAR@1%=0.9952, TAR@0.1%=0.9691
# [FL-METRIC]   Czech: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   India: EER=0.0072, TAR@1%=0.9928, TAR@0.1%=0.9880
# [FL-METRIC]   Iraq: EER=0.0000, TAR@1%=1.0000, TAR@0.1%=1.0000
# [FL-METRIC]   Malaysia: EER=0.0011, TAR@1%=1.0000, TAR@0.1%=0.9889
# [FL-METRIC]   Iran: EER=0.0247, TAR@1%=0.9627, TAR@0.1%=0.8634
# [FL-POLY] Collecting POLY regression samples (EER utility)...
# [FL-POLY] POLY buffer size: 1750 samples
# [FL-POLY] POLY model: fitted/updated (scaled -> degree-2 poly -> ridge).
# [FL-POLY] POLY score s_k: Pakistan:0.6936, China:0.6933, Czech:0.6932, India:0.6933, Iraq:0.6933, Malaysia:0.6937, Iran:0.6947
# [FL-POLY] weights_next_round: Pakistan:0.1429, China:0.1428, Czech:0.1428, India:0.1428, Iraq:0.1428, Malaysia:0.1429, Iran:0.1431
# [FL-MACRO]   Macro-EER: 0.0066
# [FL-PATIENCE]   No improvement. bad_rounds=46/150
# ✅ FHIR-POLY training finished.
# Best round: 204
# Best macro-EER: 0.004409
# Poly samples: 1750 | poly_fitted: True
# 💾 Model saved successfully at:
# C:\Users\awais\OneDrive\Desktop\Thesis\Eye_Results\FL_Stage3\FHIR_POLY_EER_best.pt
